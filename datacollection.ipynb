# %% [markdown]
# Need to write some code to grab review data for restaurants in the Bellevue area.
#
# We'll proceed with the free tier of the Google Places API.

# %% [markdown]
# <h1>Limitations</h1>
# <ul>
#     <li>Only 5 reviews per place is returned</li>
#     <li>Maximum of 60 results per query for Nearby Search and Text Search</li>
#     <li>Up to 100 queries per second</li>
#     <li>Up to $200/month of free credit to use</li>
# </ul>
# Per month, we can rougly get ~5800 Place Details calls with reviews or ~11700 Text Search calls.
#
# We'll be using Google Places API for initial discovery (name, location, ratings) and for the review data. If the search is limited to in/around Bellevue, we shouldn't exceed the monthly limits.

# %% [markdown]
# <h1>Places API (new)</h1>
# We'll be using the most recent Places API to grab the data for this project: <a href='https://developers.google.com/maps/documentation/places/web-service/overview'>https://developers.google.com/maps/documentation/places/web-service/overview</a>

# %% [markdown]
# We need to grab our API key. It's generally best not to hardcode the raw API key into a notebook, so I've set mine to an environment variable.

# %%
import os

API_KEY = os.environ.get('GOOGLE_API_KEY')

# %%
# Verify API key is loaded
API_KEY

# %% [markdown]
# After verifying that we've got our API key, we can continue to use the API to get our data.
#
# We'll start by searching for places in Bellevue, WA and listing our results.

# %%
# Bellevue coordinates
latitude = 47.6101
longitude = -122.2015

# Endpoint for Places API
url = "https://places.googleapis.com/v1/places:searchNearby"

payload = {
    "includedTypes": ["restaurant"],
    "maxResultCount": 20,
    "locationRestriction": {
        "circle": {
            "center": {
                "latitude": latitude,
                "longitude": longitude},
            "radius": 5000.0
            }
        }
    }

headers = {
    "Content-Type": "application/json",
    "X-Goog-Api-Key": API_KEY,
    "X-Goog-FieldMask": "places.id,places.displayName,places.formattedAddress,places.location,places.rating"
}

# %% [markdown]
# We can look at the header X-Goog-Fieldmask to see exactly what data we can get from this. Important here are places.id and places.location.
#
# I plan to use places.id to later get review data for each restaurant, then places.location to draw each restaurant on a map visualization.

# %%
import requests

response = requests.post(url, headers=headers, json=payload)
data = response.json()

# %%
# response
data
# Out:
# {'places': [{'id': 'ChIJrcrho4dskFQROHfX02ZeENg',
#    'formattedAddress': '10455 NE 8th St, Bellevue, WA 98004, USA',
#    'location': {'latitude': 47.617188299999995,
#     'longitude': -122.20077789999998},
#    'rating': 4.5,
#    'displayName': {'text': 'Din Tai Fung 鼎泰豐', 'languageCode': 'en'}},
#   {'id': 'ChIJic2FvopskFQRb58asxzU22E',
#    'formattedAddress': '785 116th Ave NE, Bellevue, WA 98004, USA',
#    'location': {'latitude': 47.616794, 'longitude': -122.186212},
#    'rating': 4.3,
#    'displayName': {'text': 'Chick-fil-A', 'languageCode': 'en'}},
#   {'id': 'ChIJ6R7bJwBtkFQR-XiMLLqDGME',
#    'formattedAddress': '233 106th Ave NE, Bellevue, WA 98004, USA',
#    'location': {'latitude': 47.6129752, 'longitude': -122.19923860000002},
#    'rating': 4.5,
#    'displayName': {'text': 'Tendon Kohaku', 'languageCode': 'en'}},
#   {'id': 'ChIJJ6Ov_4VskFQRu3T8pcwahmY',
#    'formattedAddress': '700 Bellevue Way NE #310, Bellevue, WA 98004, USA',
#    'location': {'latitude': 47.6168325, 'longitude': -122.20104289999999},
#    'rating': 4.2,
#    'displayName': {'text': 'Cinemark Lincoln Square Cinemas and IMAX',
#     'languageCode': 'en'}},
#   {'id': 'ChIJdSUTa4ZskFQRxsn2-IoZwto',
#    'formattedAddress': '401 Bellevue Square, Bellevue, WA 98004, USA',
#    'location': {'latitude': 47.6159663, 'longitude': -122.20210969999998},
#    'rating': 4.1,
#    'displayName': {'text': 'The Cheesecake Factory', 'languageCode': 'en'}},
#   {'id': 'ChIJwXyjgP5skFQRbKQjyqmj2qs',
#    'formattedAddress': '13102 NE 20th St, Bellevue, WA 98005, USA',
#    'location': {'latitude': 47.628321, 'longitude': -122.16556600000001},
#    'rating': 4.4,
#    'displayName': {'text': 'Mercurys Coffee Co.', 'languageCode': 'en'}},
#   {'id': 'ChIJj8eFgs9tkFQRfy1RpqzHFEY',
#    'formattedAddress': '11020 NE 6th St #90, Bellevue, WA 98004, USA',
#    'location': {'latitude': 47.6158864, 'longitude': -122.19325699999999},
#    'rating': 4.3,
#    'displayName': {'text': 'The Dolar Shop', 'languageCode': 'en'}},
#   {'id': 'ChIJo8wNCFZskFQRrlQ9Fdyv2eE',
#    'formattedAddress': '13310 NE Bel Red Rd, Bellevue, WA 98005, USA',
#    'location': {'latitude': 47.62273460000001, 'longitude': -122.1625911},
#    'rating': 4.7,
#    'displayName': {'text': 'Mox Boarding House', 'languageCode': 'en'}},
#   {'id': 'ChIJa-kOxDltkFQRg7A5nJLZM5w',
#    'formattedAddress': '266 116th Ave NE, Bellevue, WA 98004, USA',
#    'location': {'latitude': 47.612265799999996,
#     'longitude': -122.18455580000001},
#    'rating': 4.2,
#    'displayName': {'text': 'Kura Revolving Sushi Bar', 'languageCode': 'en'}},
#   {'id': 'ChIJ0VK45YltkFQReLM7YdHwu2M',
#    'formattedAddress': '11194 NE 10th St, Bellevue, WA 98004, USA',
#    'location': {'latitude': 47.619582799999996, 'longitude': -122.1913475},
#    'rating': 4.3,
#    'displayName': {'text': 'Farine Bakery & Café', 'languageCode': 'en'}},
#   {'id': 'ChIJR7EsrcptkFQRvBHLTDOJnaQ',
#    'formattedAddress': '188 106th Ave NE Suite #210, Bellevue, WA 98004, USA',
#    'location': {'latitude': 47.61179490000001,
#     'longitude': -122.19838480000001},
#    'rating': 4.7,
#    'displayName': {'text': 'Haidilao Hot Pot Bellevue', 'languageCode': 'en'}},
#   {'id': 'ChIJk6fobfttkFQRIeK9XN6jkNY',
#    'formattedAddress': '11639 NE 4th St, Bellevue, WA 98004, USA',
#    'location': {'latitude': 47.6127262, 'longitude': -122.1845741},
#    'rating': 4,
#    'displayName': {'text': "Dave & Buster's Bellevue", 'languageCode': 'en'}},
#   {'id': 'ChIJSd2HOYZskFQRkOESY01_MM0',
#    'formattedAddress': '440 Bellevue Way NE, Bellevue, WA 98004, USA',
#    'location': {'latitude': 47.6145342, 'longitude': -122.20127389999999},
#    'rating': 4.6,
#    'displayName': {'text': 'Fogo de Chão Brazilian Steakhouse',
#     'languageCode': 'en'}},
#   {'id': 'ChIJN6aOHsVskFQRl4seUuJTbwo',
#    'formattedAddress': '10606 Northup Way, Bellevue, WA 98004, USA',
#    'location': {'latitude': 47.6422388, 'longitude': -122.19881889999999},
#    'rating': 4.6,
#    'displayName': {'text': 'Burgermaster', 'languageCode': 'en'}},
#   {'id': 'ChIJpz1JKOltkFQRyKrUs09ynxc',
#    'formattedAddress': '333 108th Ave NE, Bellevue, WA 98004, USA',
#    'location': {'latitude': 47.6136208, 'longitude': -122.1969517},
#    'rating': 4.6,
#    'displayName': {'text': 'FOB Poke & Sushi Bar', 'languageCode': 'en'}},
#   {'id': 'ChIJN6EN0whtkFQR1lYGeflDEFc',
#    'formattedAddress': '10400 NE 4th St Ste 3100, Bellevue, WA 98004, USA',
#    'location': {'latitude': 47.6142129, 'longitude': -122.20077119999999},
#    'rating': 4.3,
#    'displayName': {'text': 'Ascend Prime Steak & Sushi',
#     'languageCode': 'en'}},
#   {'id': 'ChIJJ7WjO49skFQR-4IwG2Zujgg',
#    'formattedAddress': '800 Bellevue Way NE Ste 118, Bellevue, WA 98004, USA',
#    'location': {'latitude': 47.617715999999994,
#     'longitude': -122.20126299999998},
#    'rating': 4.6,
#    'displayName': {'text': 'JOEY Bellevue', 'languageCode': 'en'}},
#   {'id': 'ChIJPfieWABtkFQRmHQ_Cg8SOdQ',
#    'formattedAddress': '13841 NE 20th St, Bellevue, WA 98005, USA',
#    'location': {'latitude': 47.6275603, 'longitude': -122.15459860000001},
#    'rating': 3.7,
#    'displayName': {'text': "McDonald's", 'languageCode': 'en'}},
#   {'id': 'ChIJIb-iht9tkFQR2WUlNBbYW9s',
#    'formattedAddress': '12190 NE District Wy, Bellevue, WA 98005, USA',
#    'location': {'latitude': 47.6214656, 'longitude': -122.17776889999999},
#    'rating': 4.5,
#    'displayName': {'text': 'Bellevue Brewing Company - Spring District Brewpub',
#     'languageCode': 'en'}},
#   {'id': 'ChIJkTtnrYhskFQRuAW_QTilgLQ',
#    'formattedAddress': '700 Bellevue Way NE Unit 130, Bellevue, WA 98004, USA',
#    'location': {'latitude': 47.6163485, 'longitude': -122.20125569999999},
#    'rating': 4.3,
#    'displayName': {'text': 'Earls Kitchen + Bar', 'languageCode': 'en'}}]}

# %%
sorted_places = sorted(data["places"], key=lambda p: p.get("rating", 0), reverse=True)

for place in sorted_places:
    name = place.get("displayName", {}).get("text", "Unknown")
    address = place.get("formattedAddress", "No address")
    rating = place.get("rating", "N/A")
    id = place.get("id", "No ID found")
    print(f"- {name} ({rating}) - {address}, /// {id}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [5], in <cell line: 1>()
# ----> 1 sorted_places = sorted(data["places"], key=lambda p: p.get("rating", 0), reverse=True)
#       3 for place in sorted_places:
#       4     name = place.get("displayName", {}).get("text", "Unknown")
#
# NameError: name 'data' is not defined

# %% [markdown]
# Now that I know how to grab 20 restaurants in a X meter radius, I want to collect restaurant data in a much larger area. I'll generate a grid of circles, each with 500m radius, and get my 20 restaurants from each.

# %%
from geopy.distance import distance
from geopy.point import Point

center = Point(47.6101, -122.2015) # Bellevue city center

ns_offsets = [-1000, 0, 1000, 2000] # offsets in meters for moving north/south
ew_offsets = [-1000, 0, 1000, 2000, 3000, 4000, 5000, 6000]

grid_points = []

for dlat in ns_offsets:
    for dlon in ew_offsets:
        # dlat and dlon are changes in latitude and longitude
        point_north_south = distance(meters=dlat).destination(center, bearing=0) # a bearing of 0 is North
        final_point = distance(meters=dlon).destination(point_north_south, bearing=90) # a bearing of 90 is East
        grid_points.append((final_point.latitude, final_point.longitude))

# %%
grid_points
# Out:
# [(47.601105019802425, -122.21479808425552),
#  (47.601105790584626, -122.2015),
#  (47.601105019802425, -122.18820191574447),
#  (47.6011027074559, -122.17490383227025),
#  (47.60109885354532, -122.16160575035862),
#  (47.60109345807109, -122.14830767079087),
#  (47.60108652103385, -122.1350095943483),
#  (47.60107804243435, -122.12171152181222),
#  (47.61009922897639, -122.21480036403571),
#  (47.6101, -122.2015),
#  (47.61009922897639, -122.18819963596428),
#  (47.610096915905615, -122.17489927271049),
#  (47.61009306078795, -122.16159891102055),
#  (47.61008766362382, -122.14829855167636),
#  (47.610080724413834, -122.13499819545987),
#  (47.61007224315877, -122.12169784315299),
#  (47.61909342397967, -122.21480264492457),
#  (47.61909419524479, -122.2015),
#  (47.61909342397967, -122.18819735507542),
#  (47.61909111018441, -122.1748947109334),
#  (47.619087253859256, -122.16159206835647),
#  (47.619081855004644, -122.14828942812719),
#  (47.61907491362118, -122.1349867910281),
#  (47.61906642970964, -122.12168415784174),
#  (47.62808760481272, -122.21480492692278),
#  (47.62808837631942, -122.2015),
#  (47.62808760481272, -122.18819507307721),
#  (47.62808529029271, -122.17489014693759),
#  (47.62808143275966, -122.16158522236432),
#  (47.628076032214, -122.14828030014058),
#  (47.628069088656304, -122.13497538104956),
#  (47.62806060208739, -122.12167046587439)]

# %% [markdown]
# Now that we have our 3x3 grid of latitudes and longitudes, we'll grab all the restaurant data from GMaps.

# %%
all_places = []
num_requests = 0
for (clat, clon) in grid_points:
    num_requests += 1
    payload = {
        "includedTypes": ["restaurant"],
        "maxResultCount": 20,
        "locationRestriction": {
            "circle": {
                "center": {
                    "latitude": clat,
                    "longitude": clon},
                "radius": 500.0
                }
            }
        }

    headers = {
        "Content-Type": "application/json",
        "X-Goog-Api-Key": API_KEY,
        "X-Goog-FieldMask": "places.id,places.displayName,places.formattedAddress,places.location,places.rating"
    }

    response = requests.post(url, headers=headers, json=payload)
    data = response.json()
    if data:
        for place in data["places"]:
            location = place.get('location')
            lat = location.get('latitude')
            lon = location.get('longitude')
            new_place = {'displayName': place.get('displayName', {}).get('text', 'Unknown'),
                         'rating': place.get('rating', -1),
                         'formattedAddress': place.get('formattedAddress', 'Unknown'),
                         'id': place.get('id'),
                         'latitude': lat,
                         'longitude': lon}
            all_places.append(new_place)
print(f"Made {num_requests} requests.")
# Out:
# Made 32 requests.

# %%
all_places
# Out:
# [{'displayName': 'Dilettante Mocha Café at Bellefield Office Park',
#   'rating': 4.4,
#   'formattedAddress': 'Bellefield Office Park, Conifer Building, 1450 114th Ave SE #120, Bellevue, WA 98004, USA',
#   'id': 'ChIJUaS2CnRskFQRgkVy8FFKcKE',
#   'latitude': 47.597937099999996,
#   'longitude': -122.18787809999999},
#  {'displayName': 'Polaris Restaurant',
#   'rating': 3.7,
#   'formattedAddress': '11200 SE 6th St, Bellevue, WA 98004, USA',
#   'id': 'ChIJtToSvHpskFQR9plO2_RX048',
#   'latitude': 47.605349499999996,
#   'longitude': -122.1895634},
#  {'displayName': 'Rivue Bar and Grill',
#   'rating': 4.1,
#   'formattedAddress': '605 114th Ave SE, Bellevue, WA 98004, USA',
#   'id': 'ChIJAy-pHnBskFQRYYC9N_vXHLo',
#   'latitude': 47.6039125,
#   'longitude': -122.1864034},
#  {'displayName': 'TRES Sandwich',
#   'rating': 4.7,
#   'formattedAddress': '1502 145th Pl SE, Bellevue, WA 98007, USA',
#   'id': 'ChIJwTsohjxskFQRZTRFHsbBl1o',
#   'latitude': 47.5969828,
#   'longitude': -122.15012670000002},
#  {'displayName': 'Tokyo Stop Teriyaki',
#   'rating': 4.5,
#   'formattedAddress': '1504 145th Pl SE, Bellevue, WA 98007, USA',
#   'id': 'ChIJy59LiTxskFQRDfTH40WrfvU',
#   'latitude': 47.5970278,
#   'longitude': -122.1498502},
#  {'displayName': "Papa Murphy's | Take 'N' Bake Pizza",
#   'rating': 4.1,
#   'formattedAddress': 'next to QFC, 1500 145th Pl SE Suite 4, Bellevue, WA 98007, USA',
#   'id': 'ChIJYbU_RjNskFQRYwg0qDUEi08',
#   'latitude': 47.5969759,
#   'longitude': -122.14977160000001},
#  {'displayName': 'Tacos Paraíso',
#   'rating': 3,
#   'formattedAddress': '903 142nd Ave SE, Bellevue, WA 98007, USA',
#   'id': 'ChIJy_vSFkJtkFQR4bNxqtk6-w4',
#   'latitude': 47.602038199999996,
#   'longitude': -122.15105620000001},
#  {'displayName': 'YGF MaLaTang Bellevue',
#   'rating': 4.1,
#   'formattedAddress': '683 156th Ave SE, Bellevue, WA 98007, USA',
#   'id': 'ChIJXdThK_ptkFQRxsxeH_wkqws',
#   'latitude': 47.6040978,
#   'longitude': -122.13271249999998},
#  {'displayName': "Jayam's Tiffins and Thali",
#   'rating': 4.2,
#   'formattedAddress': '15546 Lake Hills Blvd, Bellevue, WA 98007, USA',
#   'id': 'ChIJhYTLWGRtkFQR1kOOMKewGJM',
#   'latitude': 47.6035652,
#   'longitude': -122.13231789999999},
#  {'displayName': 'IFB Market',
#   'rating': 3.8,
#   'formattedAddress': '655 156th Ave SE Suite A103, Bellevue, WA 98007, USA',
#   'id': 'ChIJHwWvUaVtkFQRef7hKkN7r9w',
#   'latitude': 47.6038218,
#   'longitude': -122.13161500000001},
#  {'displayName': 'Malay Satay Hut',
#   'rating': 3.9,
#   'formattedAddress': '667 156th Ave SE, Bellevue, WA 98007, USA',
#   'id': 'ChIJE4jaAAptkFQRemASJ3WrBg4',
#   'latitude': 47.6043087,
#   'longitude': -122.13274669999998},
#  {'displayName': 'Shabu Shabu Kyoto',
#   'rating': 4.4,
#   'formattedAddress': '627 156th Ave SE, Bellevue, WA 98007, USA',
#   'id': 'ChIJOYOFQjNskFQRQvaNYdeXpLk',
#   'latitude': 47.604612499999995,
#   'longitude': -122.132511},
#  {'displayName': 'Naturalz Ice Cream',
#   'rating': 4.9,
#   'formattedAddress': '655 156th Ave SE Suite A108, Bellevue, WA 98007, USA',
#   'id': 'ChIJaTpiqDdtkFQRyS_4lTmp9G8',
#   'latitude': 47.604156599999996,
#   'longitude': -122.13176729999999},
#  {'displayName': 'BRUNCHBAR',
#   'rating': 4.4,
#   'formattedAddress': '623 156th Ave SE, Bellevue, WA 98007, USA',
#   'id': 'ChIJP6-XNg1tkFQRQI6F7ENuOqY',
#   'latitude': 47.6046388,
#   'longitude': -122.132288},
#  {'displayName': 'Lin Handmade Dumplings',
#   'rating': 3.6,
#   'formattedAddress': '677 156th Ave SE, Bellevue, WA 98007, USA',
#   'id': 'ChIJszruQABtkFQR0pcHTYqk8QE',
#   'latitude': 47.6041729,
#   'longitude': -122.1326407},
#  {'displayName': 'Sammy’s Food Truck',
#   'rating': 4.9,
#   'formattedAddress': '15231 Lake Hills Blvd, Bellevue, WA 98007, USA',
#   'id': 'ChIJBakmJwBtkFQRLpGIA33WIIQ',
#   'latitude': 47.602325699999994,
#   'longitude': -122.1359451},
#  {'displayName': 'Tendon Kohaku',
#   'rating': 4.5,
#   'formattedAddress': '233 106th Ave NE, Bellevue, WA 98004, USA',
#   'id': 'ChIJ6R7bJwBtkFQR-XiMLLqDGME',
#   'latitude': 47.6129752,
#   'longitude': -122.19923860000002},
#  {'displayName': 'Haidilao Hot Pot Bellevue',
#   'rating': 4.7,
#   'formattedAddress': '188 106th Ave NE Suite #210, Bellevue, WA 98004, USA',
#   'id': 'ChIJR7EsrcptkFQRvBHLTDOJnaQ',
#   'latitude': 47.61179490000001,
#   'longitude': -122.19838480000001},
#  {'displayName': 'Fogo de Chão Brazilian Steakhouse',
#   'rating': 4.6,
#   'formattedAddress': '440 Bellevue Way NE, Bellevue, WA 98004, USA',
#   'id': 'ChIJSd2HOYZskFQRkOESY01_MM0',
#   'latitude': 47.6145342,
#   'longitude': -122.20127389999999},
#  {'displayName': 'Ascend Prime Steak & Sushi',
#   'rating': 4.3,
#   'formattedAddress': '10400 NE 4th St Ste 3100, Bellevue, WA 98004, USA',
#   'id': 'ChIJN6EN0whtkFQR1lYGeflDEFc',
#   'latitude': 47.6142129,
#   'longitude': -122.20077119999999},
#  {'displayName': 'Nana’s Green Tea',
#   'rating': 4.3,
#   'formattedAddress': '16 103rd Ave NE, Bellevue, WA 98004, USA',
#   'id': 'ChIJeahpu0ltkFQRItNlPE0Wslc',
#   'latitude': 47.6106023,
#   'longitude': -122.2026693},
#  {'displayName': 'Hokkaido Ramen Santouka Bellevue',
#   'rating': 4.4,
#   'formattedAddress': '3rd, 103 Bellevue Way NE Suite 3, Bellevue, WA 98004, USA',
#   'id': 'ChIJTaRy231skFQRF8u2jBrpyl4',
#   'latitude': 47.6113247,
#   'longitude': -122.2020972},
#  {'displayName': 'Lincoln Square South',
#   'rating': 4.5,
#   'formattedAddress': '500 Bellevue Way NE, Bellevue, WA 98004, USA',
#   'id': 'ChIJG586rIhskFQROohpT2geS10',
#   'latitude': 47.6142475,
#   'longitude': -122.2007738},
#  {'displayName': 'Fern Thai on Main (Bellevue)',
#   'rating': 4.2,
#   'formattedAddress': '10134 Main St, Bellevue, WA 98004, USA',
#   'id': 'ChIJQX7ANqFtkFQRmfzOyNMLa4U',
#   'latitude': 47.61036550000001,
#   'longitude': -122.2046284},
#  {'displayName': "Carmine's",
#   'rating': 4.5,
#   'formattedAddress': '88 102nd Ave NE, Bellevue, WA 98004, USA',
#   'id': 'ChIJtaDvTYdskFQRPFeF4DNV3pg',
#   'latitude': 47.611089799999995,
#   'longitude': -122.20387880000001},
#  {'displayName': 'Dough Zone Dumpling House Bellevue',
#   'rating': 4.2,
#   'formattedAddress': '10300 Main St Suite E, Bellevue, WA 98004, USA',
#   'id': 'ChIJl0CSabBtkFQRrqopqhRluJw',
#   'latitude': 47.610329199999995,
#   'longitude': -122.20258549999998},
#  {'displayName': 'Chipotle Mexican Grill',
#   'rating': 3.8,
#   'formattedAddress': '10503 NE 4th St, Bellevue, WA 98004, USA',
#   'id': 'ChIJW4VXzodskFQRseSBkOHh9Vg',
#   'latitude': 47.6135495,
#   'longitude': -122.1997845},
#  {'displayName': 'Cinemark Reserve Lincoln Square — Dine-In 21+',
#   'rating': 4.5,
#   'formattedAddress': '500 Bellevue Way NE suit 340, Bellevue, WA 98004, USA',
#   'id': 'ChIJadMls4hskFQRqB-iUD6wmLU',
#   'latitude': 47.614579,
#   'longitude': -122.20126},
#  {'displayName': 'Desi Tadka Indian Grill',
#   'rating': 4.3,
#   'formattedAddress': '304 105th Ave NE, Bellevue, WA 98004, USA',
#   'id': 'ChIJ3y0GZ71tkFQRmK2dgqcWIOI',
#   'latitude': 47.612849399999995,
#   'longitude': -122.1997081},
#  {'displayName': 'Lao Ma Tou Hot Pot 老码头火锅',
#   'rating': 4.4,
#   'formattedAddress': '288 106th Ave NE #200, Bellevue, WA 98004, USA',
#   'id': 'ChIJLyj05b1tkFQRJOwhq9mKm4o',
#   'latitude': 47.612688399999996,
#   'longitude': -122.19840370000001},
#  {'displayName': 'La Mar Cocina Peruana Bellevue',
#   'rating': 4.6,
#   'formattedAddress': '10508 Main St, Bellevue, WA 98004, USA',
#   'id': 'ChIJQz-iSbptkFQRp4NvMytxnyI',
#   'latitude': 47.610300699999996,
#   'longitude': -122.199567},
#  {'displayName': 'Seastar Restaurant & Raw Bar',
#   'rating': 4.5,
#   'formattedAddress': '205 108th Ave NE, Bellevue, WA 98004, USA',
#   'id': 'ChIJd2uY_zUVkFQRnYtbBRLwOJg',
#   'latitude': 47.6123799,
#   'longitude': -122.1964909},
#  {'displayName': 'Monsoon Bellevue',
#   'rating': 4.3,
#   'formattedAddress': '10245 Main St Unit 103, Bellevue, WA 98004, USA',
#   'id': 'ChIJx5Zt_X1skFQRiGO0IbDii1U',
#   'latitude': 47.610059799999995,
#   'longitude': -122.2031227},
#  {'displayName': '520 Bar & Grill',
#   'rating': 4.4,
#   'formattedAddress': '10146 Main St, Bellevue, WA 98004, USA',
#   'id': 'ChIJhY1xAn5skFQR740cPn2c5Kc',
#   'latitude': 47.610300699999996,
#   'longitude': -122.20431},
#  {'displayName': "Araya's Place Vegan Thai Bellevue",
#   'rating': 4.5,
#   'formattedAddress': '10246 Main St C, Bellevue, WA 98004, USA',
#   'id': 'ChIJX1ir8n1skFQRW3dgnlJ3fp0',
#   'latitude': 47.610282399999996,
#   'longitude': -122.20304840000001},
#  {'displayName': 'Bellden Cafe',
#   'rating': 4.3,
#   'formattedAddress': '10527 Main St, Bellevue, WA 98004, USA',
#   'id': 'ChIJ56sNpH1skFQRa4jznGtK-WY',
#   'latitude': 47.610006899999995,
#   'longitude': -122.19957500000001},
#  {'displayName': 'Kura Revolving Sushi Bar',
#   'rating': 4.2,
#   'formattedAddress': '266 116th Ave NE, Bellevue, WA 98004, USA',
#   'id': 'ChIJa-kOxDltkFQRg7A5nJLZM5w',
#   'latitude': 47.612265799999996,
#   'longitude': -122.18455580000001},
#  {'displayName': "Dave & Buster's Bellevue",
#   'rating': 4,
#   'formattedAddress': '11639 NE 4th St, Bellevue, WA 98004, USA',
#   'id': 'ChIJk6fobfttkFQRIeK9XN6jkNY',
#   'latitude': 47.6127262,
#   'longitude': -122.1845741},
#  {'displayName': 'Chipotle Mexican Grill',
#   'rating': 3.4,
#   'formattedAddress': '376 116th Ave NE, Bellevue, WA 98004, USA',
#   'id': 'ChIJYz8LN41tkFQRdMadR-atjKc',
#   'latitude': 47.612679899999996,
#   'longitude': -122.1853223},
#  {'displayName': 'Solarium Kitchen & Bar',
#   'rating': 3.8,
#   'formattedAddress': '300 112th Ave SE, Bellevue, WA 98004, USA',
#   'id': 'ChIJz52GO-BtkFQR7FJgJxet_K4',
#   'latitude': 47.606913899999995,
#   'longitude': -122.1888214},
#  {'displayName': 'Amuse Bar + Restaurant',
#   'rating': 3.2,
#   'formattedAddress': '200 110th Ave NE, Bellevue, WA 98004, USA',
#   'id': 'ChIJm4PPc7xtkFQR4E9KLGaglU4',
#   'latitude': 47.6126356,
#   'longitude': -122.1928186},
#  {'displayName': 'Evergreen Point Bistro',
#   'rating': 5,
#   'formattedAddress': '71 112th Ave NE, Bellevue, WA 98004, USA',
#   'id': 'ChIJO1IAVJ9tkFQRT9O8RYD1XCQ',
#   'latitude': 47.610739699999996,
#   'longitude': -122.19122979999999},
#  {'displayName': "Poppinjay's A Cafe",
#   'rating': 4.2,
#   'formattedAddress': '150 120th Ave NE, Bellevue, WA 98005, USA',
#   'id': 'ChIJgxLWrkFtkFQRMkHthXME8wo',
#   'latitude': 47.612047,
#   'longitude': -122.17968839999999},
#  {'displayName': 'Kizuki Ramen & Izakaya',
#   'rating': 4.5,
#   'formattedAddress': '14845 Main St, Bellevue, WA 98007, USA',
#   'id': 'ChIJl4sSWkpskFQRG59oX-GVfyM',
#   'latitude': 47.609612,
#   'longitude': -122.1417149},
#  {'displayName': 'La Chingona Mexican Cuisine Bellevue',
#   'rating': 4.8,
#   'formattedAddress': '29 148th Ave SE, Bellevue, WA 98007, USA',
#   'id': 'ChIJK0J_NFFtkFQRxK1pl1y4y2w',
#   'latitude': 47.6088774,
#   'longitude': -122.14350230000001},
#  {'displayName': 'Starbucks',
#   'rating': 4.1,
#   'formattedAddress': '180 148th Ave SE, Bellevue, WA 98007, USA',
#   'id': 'ChIJ48yWhkpskFQRPDYWFGjz1fM',
#   'latitude': 47.6090903,
#   'longitude': -122.1426207},
#  {'displayName': 'Best Wok Restaurant',
#   'rating': 4.3,
#   'formattedAddress': '19 148th Ave NE, Bellevue, WA 98007, USA',
#   'id': 'ChIJDT9eTUpskFQRbGHjQb6qBvA',
#   'latitude': 47.6103307,
#   'longitude': -122.14359189999999},
#  {'displayName': '7-Eleven',
#   'rating': 2.8,
#   'formattedAddress': '15 148th Ave NE, Bellevue, WA 98007, USA',
#   'id': 'ChIJTYqOTEpskFQRjIUZ-CWfJDc',
#   'latitude': 47.6101211,
#   'longitude': -122.1435588},
#  {'displayName': 'Greek Express',
#   'rating': 4.3,
#   'formattedAddress': '14835 Main St, Bellevue, WA 98007, USA',
#   'id': 'ChIJ349-WkpskFQROukGnSeucJs',
#   'latitude': 47.609617899999996,
#   'longitude': -122.14179469999999},
#  {'displayName': 'Shell',
#   'rating': 2.6,
#   'formattedAddress': '11 148th Ave SE, Bellevue, WA 98007, USA',
#   'id': 'ChIJufz9R0pskFQRHcCWY6u0qgw',
#   'latitude': 47.609559399999995,
#   'longitude': -122.1433871},
#  {'displayName': "O'Bop",
#   'rating': 4.7,
#   'formattedAddress': '11 148th Ave SE, Bellevue, WA 98007, USA',
#   'id': 'ChIJe6ECOEpskFQRGB4VeYsyLG0',
#   'latitude': 47.6095474,
#   'longitude': -122.14330579999998},
#  {'displayName': 'Lunch on the Plate',
#   'rating': 5,
#   'formattedAddress': 'Bellevue, WA 98007, USA',
#   'id': 'ChIJiRX5BABtkFQRdqghUpCxzNg',
#   'latitude': 47.610558999999995,
#   'longitude': -122.14242579999998},
#  {'displayName': 'Wingstop',
#   'rating': 3.7,
#   'formattedAddress': '14875 Main St, Bellevue, WA 98007, USA',
#   'id': 'ChIJxXEwXkpskFQRz4KVeSenNeM',
#   'latitude': 47.6096353,
#   'longitude': -122.14142299999999},
#  {'displayName': "Menchie's Frozen Yogurt",
#   'rating': 4.3,
#   'formattedAddress': '14865 Main St, Bellevue, WA 98007, USA',
#   'id': 'ChIJccoDWUpskFQRUb5KVLAHRKw',
#   'latitude': 47.609553,
#   'longitude': -122.14151999999999},
#  {'displayName': 'STALLION',
#   'rating': 5,
#   'formattedAddress': '15053 Main St, Bellevue, WA 98007, USA',
#   'id': 'ChIJS9Jhy9NtkFQR4I_p0qD3BUo',
#   'latitude': 47.6094285,
#   'longitude': -122.13984869999997},
#  {'displayName': 'Din Tai Fung 鼎泰豐',
#   'rating': 4.5,
#   'formattedAddress': '10455 NE 8th St, Bellevue, WA 98004, USA',
#   'id': 'ChIJrcrho4dskFQROHfX02ZeENg',
#   'latitude': 47.617188299999995,
#   'longitude': -122.20077789999998},
#  {'displayName': 'Cinemark Lincoln Square Cinemas and IMAX',
#   'rating': 4.2,
#   'formattedAddress': '700 Bellevue Way NE #310, Bellevue, WA 98004, USA',
#   'id': 'ChIJJ6Ov_4VskFQRu3T8pcwahmY',
#   'latitude': 47.6168325,
#   'longitude': -122.20104289999999},
#  {'displayName': 'The Cheesecake Factory',
#   'rating': 4.1,
#   'formattedAddress': '401 Bellevue Square, Bellevue, WA 98004, USA',
#   'id': 'ChIJdSUTa4ZskFQRxsn2-IoZwto',
#   'latitude': 47.6159663,
#   'longitude': -122.20210969999998},
#  {'displayName': 'JOEY Bellevue',
#   'rating': 4.6,
#   'formattedAddress': '800 Bellevue Way NE Ste 118, Bellevue, WA 98004, USA',
#   'id': 'ChIJJ7WjO49skFQR-4IwG2Zujgg',
#   'latitude': 47.617715999999994,
#   'longitude': -122.20126299999998},
#  {'displayName': 'Earls Kitchen + Bar',
#   'rating': 4.3,
#   'formattedAddress': '700 Bellevue Way NE Unit 130, Bellevue, WA 98004, USA',
#   'id': 'ChIJkTtnrYhskFQRuAW_QTilgLQ',
#   'latitude': 47.6163485,
#   'longitude': -122.20125569999999},
#  {'displayName': 'Cactus Bellevue Square',
#   'rating': 4.4,
#   'formattedAddress': '535 Bellevue Square, Bellevue, WA 98004, USA',
#   'id': 'ChIJ8eP5VY9skFQRj_eSuT7hnhM',
#   'latitude': 47.6167922,
#   'longitude': -122.20205290000001},
#  {'displayName': "Wendy's",
#   'rating': 3.6,
#   'formattedAddress': '940 Bellevue Way NE, Bellevue, WA 98004, USA',
#   'id': 'ChIJfWGsCI9skFQRtz6-s4xwviA',
#   'latitude': 47.61904,
#   'longitude': -122.20125360000002},
#  {'displayName': "Inchin's Bamboo Garden",
#   'rating': 4.1,
#   'formattedAddress': '601 108th Ave NE Keycenter Building #120, Bellevue, WA 98004, USA',
#   'id': 'ChIJDe84_YhskFQRrY6jFMbAlrU',
#   'latitude': 47.6160572,
#   'longitude': -122.19677539999999},
#  {'displayName': 'Tavern Hall',
#   'rating': 4.3,
#   'formattedAddress': '505 Bellevue Square, Bellevue, WA 98004, USA',
#   'id': 'ChIJ3bYQeY53CEER9LMe4keT1yM',
#   'latitude': 47.616440999999995,
#   'longitude': -122.20205800000001},
#  {'displayName': 'Japonessa Sushi Cocina',
#   'rating': 4.4,
#   'formattedAddress': '500 Bellevue Way NE Suite 130, Bellevue, WA 98004, USA',
#   'id': 'ChIJN1LvMYZskFQRhDtKQaB_VWQ',
#   'latitude': 47.614850499999996,
#   'longitude': -122.200976},
#  {'displayName': 'Wild Ginger Bellevue',
#   'rating': 4.1,
#   'formattedAddress': '508 Bellevue Way NE, Bellevue, WA 98004, USA',
#   'id': 'ChIJl9MGlIlskFQRkiKWMYy2cqU',
#   'latitude': 47.6149694,
#   'longitude': -122.20127869999997},
#  {'displayName': 'Shake Shack Bellevue Square',
#   'rating': 3.6,
#   'formattedAddress': '503 Bellevue Way NE, Bellevue, WA 98004, USA',
#   'id': 'ChIJfckYPg5tkFQRJ4aBmyL5-oE',
#   'latitude': 47.6163325,
#   'longitude': -122.2019684},
#  {'displayName': 'Duke’s Seafood Bellevue',
#   'rating': 4.5,
#   'formattedAddress': '500 Bellevue Way NE Ste 212, Bellevue, WA 98004, USA',
#   'id': 'ChIJw7mdDIZskFQR9crrY1PXtpc',
#   'latitude': 47.6149075,
#   'longitude': -122.2013098},
#  {'displayName': 'Cafe Hagen (Modern Scandinavian All Day Restaurant and Cocktail Bar)',
#   'rating': 4.3,
#   'formattedAddress': '777 108th Ave NE Suite 1850, Bellevue, WA 98004, USA',
#   'id': 'ChIJPVMVVABtkFQR79rTIEQnnjI',
#   'latitude': 47.6166329,
#   'longitude': -122.1969857},
#  {'displayName': 'STK Steakhouse',
#   'rating': 4.6,
#   'formattedAddress': '610 Bellevue Way NE #110, Bellevue, WA 98004, USA',
#   'id': 'ChIJoUD1o-JtkFQRwcwHjIguOZE',
#   'latitude': 47.6159769,
#   'longitude': -122.20127719999999},
#  {'displayName': 'Boiling Point',
#   'rating': 4,
#   'formattedAddress': '1075 Bellevue Way NE, Bellevue, WA 98004, USA',
#   'id': 'ChIJcYllSY5skFQR6nwQnUGLsQA',
#   'latitude': 47.61985490000001,
#   'longitude': -122.20279520000001},
#  {'displayName': 'Cantina Monarca',
#   'rating': 4.1,
#   'formattedAddress': '504 Bellevue Way NE, Bellevue, WA 98004, USA',
#   'id': 'ChIJ-_xduBBtkFQRbiAn-xoqh9k',
#   'latitude': 47.614787799999995,
#   'longitude': -122.2012932},
#  {'displayName': 'Castilla Restaurant and Tapas Bar',
#   'rating': 4.1,
#   'formattedAddress': '504 Bellevue Square, Bellevue, WA 98004, USA',
#   'id': 'ChIJqyWGR8ttkFQRmbV4DG1N088',
#   'latitude': 47.6165048,
#   'longitude': -122.20196440000001},
#  {'displayName': 'Panera Bread',
#   'rating': 3.9,
#   'formattedAddress': '1100 Bellevue Way NE Suite 900, Bellevue, WA 98004, USA',
#   'id': 'ChIJgeoRTY5skFQRbUTOT0xjmEY',
#   'latitude': 47.6204748,
#   'longitude': -122.19956979999999},
#  {'displayName': 'Farzi Café',
#   'rating': 3.9,
#   'formattedAddress': '515 Bellevue Square, Bellevue, WA 98004, USA',
#   'id': 'ChIJfYkCkGttkFQRv4gGvJhIT7I',
#   'latitude': 47.6166203,
#   'longitude': -122.20207359999999},
#  {'displayName': 'Chick-fil-A',
#   'rating': 4.3,
#   'formattedAddress': '785 116th Ave NE, Bellevue, WA 98004, USA',
#   'id': 'ChIJic2FvopskFQRb58asxzU22E',
#   'latitude': 47.616794,
#   'longitude': -122.186212},
#  {'displayName': 'Farine Bakery & Café',
#   'rating': 4.3,
#   'formattedAddress': '11194 NE 10th St, Bellevue, WA 98004, USA',
#   'id': 'ChIJ0VK45YltkFQReLM7YdHwu2M',
#   'latitude': 47.619582799999996,
#   'longitude': -122.1913475},
#  {'displayName': 'Chutneys Bellevue',
#   'rating': 4.1,
#   'formattedAddress': 'City Square App, 938 110th Ave NE #5, Bellevue, WA 98004, USA',
#   'id': 'ChIJqaI8qextkFQRD3kVJeWS6gA',
#   'latitude': 47.618498699999996,
#   'longitude': -122.1933538},
#  {'displayName': 'Cielo Cocina Mexicana',
#   'rating': 4.4,
#   'formattedAddress': '958 111th Ave NE #101, Bellevue, WA 98004, USA',
#   'id': 'ChIJgdsj1i9tkFQROd1zHVywx3w',
#   'latitude': 47.6184044,
#   'longitude': -122.1917823},
#  {'displayName': 'The Pumphouse Bar & Grill',
#   'rating': 4.5,
#   'formattedAddress': '11802 NE 8th St, Bellevue, WA 98005, USA',
#   'id': 'ChIJM5qcUPVskFQR_1535D5ymes',
#   'latitude': 47.617782399999996,
#   'longitude': -122.1830679},
#  {'displayName': 'Woobling Korean BBQ',
#   'rating': 4.4,
#   'formattedAddress': '989 112th Ave NE #205, Bellevue, WA 98004, USA',
#   'id': 'ChIJC9jIwOBtkFQRdLhQh8gXe50',
#   'latitude': 47.619241599999995,
#   'longitude': -122.1912554},
#  {'displayName': 'Tanoor Bellevue',
#   'rating': 4.3,
#   'formattedAddress': '989 112th Ave NE #105, Bellevue, WA 98004, USA',
#   'id': 'ChIJbXvZWKdtkFQRoXDGF_-Rx3c',
#   'latitude': 47.619105999999995,
#   'longitude': -122.1913479},
#  {'displayName': 'Burger King',
#   'rating': 3.2,
#   'formattedAddress': '11723 NE 8th St, Bellevue, WA 98005, USA',
#   'id': 'ChIJy87w_19skFQRDS0TJrRvfIA',
#   'latitude': 47.616817999999995,
#   'longitude': -122.18338209999999},
#  {'displayName': 'John Howie Steak',
#   'rating': 4.5,
#   'formattedAddress': '11111 NE 8th St #125, Bellevue, WA 98004, USA',
#   'id': 'ChIJ06MLNIpskFQR9w8k4jegAIk',
#   'latitude': 47.6167847,
#   'longitude': -122.19119200000002},
#  {'displayName': 'I Love Sushi on Lake Bellevue',
#   'rating': 4.4,
#   'formattedAddress': '23 Lake Bellevue Dr, Bellevue, WA 98005, USA',
#   'id': 'ChIJ8ZMXUPVskFQRwauXeAX8OsE',
#   'latitude': 47.619049999999994,
#   'longitude': -122.18174630000001},
#  {'displayName': 'Minamoto Japanese Cuisine',
#   'rating': 4.3,
#   'formattedAddress': '11011 NE 9th St, Bellevue, WA 98004, USA',
#   'id': 'ChIJcXyzxotskFQRJStVIDo8N9k',
#   'latitude': 47.618056800000005,
#   'longitude': -122.1922324},
#  {'displayName': 'Wild Wasabi Signature',
#   'rating': 4.4,
#   'formattedAddress': '909 112th Ave NE #109, Bellevue, WA 98004, USA',
#   'id': 'ChIJpxEbFeRtkFQRlGGi7NWUrkU',
#   'latitude': 47.618223199999996,
#   'longitude': -122.19123040000001},
#  {'displayName': 'Master Bing (Bellevue) 煎饼师傅',
#   'rating': 4.9,
#   'formattedAddress': '11116 NE 10th St #201, Bellevue, WA 98004, USA',
#   'id': 'ChIJH14YNQBtkFQRgIKh2GePB6k',
#   'latitude': 47.6196622,
#   'longitude': -122.1917532},
#  {'displayName': 'The French Bakery',
#   'rating': 4,
#   'formattedAddress': '909 112th Ave NE #106, Bellevue, WA 98004, USA',
#   'id': 'ChIJCa_-oYtskFQRlSDGGMptrzc',
#   'latitude': 47.6184218,
#   'longitude': -122.19119350000001},
#  {'displayName': 'Kobe Bellevue Restaurant',
#   'rating': 4.2,
#   'formattedAddress': '850 110th Ave NE #5147, Bellevue, WA 98004, USA',
#   'id': 'ChIJ8SdzYolskFQRHPD-d1FAsmA',
#   'latitude': 47.618075999999995,
#   'longitude': -122.1933311},
#  {'displayName': 'Andiamo Italian Ristorante',
#   'rating': 4.3,
#   'formattedAddress': '938 110th Ave NE #1, Bellevue, WA 98004, USA',
#   'id': 'ChIJWcgO7otskFQRtAt-mPBzWRc',
#   'latitude': 47.6191876,
#   'longitude': -122.1934528},
#  {'displayName': 'Cafe Joy',
#   'rating': 4.2,
#   'formattedAddress': '11004 NE 11th St, Bellevue, WA 98004, USA',
#   'id': 'ChIJy7o1jjFtkFQRzh5phIdE3ig',
#   'latitude': 47.620316599999995,
#   'longitude': -122.19328549999999},
#  {'displayName': 'Starbucks',
#   'rating': 4.1,
#   'formattedAddress': '1231 116th Ave NE #25, Bellevue, WA 98004, USA',
#   'id': 'ChIJpT9jovNskFQRrE4rAq2ZW2o',
#   'latitude': 47.621118499999994,
#   'longitude': -122.18605119999998},
#  {'displayName': 'ampm',
#   'rating': 2.6,
#   'formattedAddress': '11611 NE 8th St, Bellevue, WA 98005, USA',
#   'id': 'ChIJIwSLsIpskFQRukwa7TCmJYg',
#   'latitude': 47.616935999999995,
#   'longitude': -122.184877},
#  {'displayName': 'Pasifika Grill & Bar',
#   'rating': 4.8,
#   'formattedAddress': '625 116th Ave NE, Bellevue, WA 98004, USA',
#   'id': 'ChIJ4ShA-ZRtkFQRjAO-tYV4nYU',
#   'latitude': 47.6159926,
#   'longitude': -122.18672869999997},
#  {'displayName': 'Bellevue Brewing Company - Spring District Brewpub',
#   'rating': 4.5,
#   'formattedAddress': '12190 NE District Wy, Bellevue, WA 98005, USA',
#   'id': 'ChIJIb-iht9tkFQR2WUlNBbYW9s',
#   'latitude': 47.6214656,
#   'longitude': -122.17776889999999},
#  {'displayName': 'Phở Ever',
#   'rating': 4.1,
#   'formattedAddress': '12015 NE 8th St, Bellevue, WA 98005, USA',
#   'id': 'ChIJQ90bn19skFQRWNHekYHMF0g',
#   'latitude': 47.617027799999995,
#   'longitude': -122.1793565},
#  {'displayName': 'Facing East | Taiwanese Restaurant',
#   'rating': 4.3,
#   'formattedAddress': '12736 NE Bel Red Rd, Bellevue, WA 98005, USA',
#   'id': 'ChIJ_8Dquo9skFQRx3XvidLWtAU',
#   'latitude': 47.621603799999995,
#   'longitude': -122.17027809999999},
#  {'displayName': 'The Crab Pot Bellevue',
#   'rating': 3.9,
#   'formattedAddress': '2 Lake Bellevue Dr, Bellevue, WA 98005, USA',
#   'id': 'ChIJJydJyvVskFQR-zw-Ys-EHSI',
#   'latitude': 47.6202921,
#   'longitude': -122.18053379999999},
#  {'displayName': 'The Goose Pub & Eatery',
#   'rating': 4.2,
#   'formattedAddress': '12001 NE 12th St, Bellevue, WA 98005, USA',
#   'id': 'ChIJBeN62_VskFQRolgeXT5Ho5k',
#   'latitude': 47.6197406,
#   'longitude': -122.178889},
#  {'displayName': 'GREEN APPLE DELI-(Spring Deli)',
#   'rating': 5,
#   'formattedAddress': '12288 NE District Wy #135, Bellevue, WA 98005, USA',
#   'id': 'ChIJ5RrDBfdtkFQREvVY-di169Q',
#   'latitude': 47.621639599999995,
#   'longitude': -122.17641069999999},
#  {'displayName': 'Spring Deli & Market/Greenapple Deli',
#   'rating': 4.1,
#   'formattedAddress': '12288 NE District Wy #135, Bellevue, WA 98005, USA',
#   'id': 'ChIJXzKCD1RtkFQRNdI9Qgprh-4',
#   'latitude': 47.621368,
#   'longitude': -122.17654489999998},
#  {'displayName': 'Hot Ones™ by The Goose Pub & Eatery',
#   'rating': 3,
#   'formattedAddress': '12001 NE 12th St, Bellevue, WA 98005, USA',
#   'id': 'ChIJNXrROqZtkFQRk_0Xd0XDkoo',
#   'latitude': 47.6199781,
#   'longitude': -122.17880579999999},
#  {'displayName': 'Mox Boarding House',
#   'rating': 4.7,
#   'formattedAddress': '13310 NE Bel Red Rd, Bellevue, WA 98005, USA',
#   'id': 'ChIJo8wNCFZskFQRrlQ9Fdyv2eE',
#   'latitude': 47.62273460000001,
#   'longitude': -122.1625911},
#  {'displayName': 'Tasty Szechuan',
#   'rating': 4.1,
#   'formattedAddress': '707 148th Ave NE, Bellevue, WA 98007, USA',
#   'id': 'ChIJD0hdWDVtkFQRe9_Szi0YSeA',
#   'latitude': 47.616268399999996,
#   'longitude': -122.14366700000001},
#  {'displayName': 'Los Chilangos - Bellevue',
#   'rating': 4.5,
#   'formattedAddress': '14008 NE 8th St, Bellevue, WA 98007, USA',
#   'id': 'ChIJ-aPkXRJtkFQRkQF6GuYUVKc',
#   'latitude': 47.6174415,
#   'longitude': -122.1531425},
#  {'displayName': "Dick's Drive-In",
#   'rating': 4.4,
#   'formattedAddress': '15600 NE 8th St Suite O-1, Bellevue, WA 98008, USA',
#   'id': 'ChIJk6TU-fVtkFQRHHsWN5iFekU',
#   'latitude': 47.620503299999996,
#   'longitude': -122.12976739999999},
#  {'displayName': 'Happy Lamb Hot Pot',
#   'rating': 4.4,
#   'formattedAddress': '1411 156th Ave NE STE A, Bellevue, WA 98007, USA',
#   'id': 'ChIJpc0kaKVtkFQR38bRWg4u5UU',
#   'latitude': 47.6231225,
#   'longitude': -122.13325689999999},
#  {'displayName': 'Banaras',
#   'rating': 4.4,
#   'formattedAddress': '15600 NE 8th St Suite O9, Bellevue, WA 98008, USA',
#   'id': 'ChIJJQ8XECttkFQRaKaC5o3mftY',
#   'latitude': 47.6208172,
#   'longitude': -122.1305419},
#  {'displayName': 'Ten Seconds Yunnan Rice Noodle',
#   'rating': 4,
#   'formattedAddress': '1299 156th Ave NE Ste 135, Bellevue, WA 98007, USA',
#   'id': 'ChIJURH1KkRtkFQR9SGpm7mW9PU',
#   'latitude': 47.621348499999996,
#   'longitude': -122.13323090000002},
#  {'displayName': "McDonald's",
#   'rating': 3.6,
#   'formattedAddress': '1401 156th Ave NE, Bellevue, WA 98007, USA',
#   'id': 'ChIJ2UERRaVtkFQRa1rqRwl8Juc',
#   'latitude': 47.622564499999996,
#   'longitude': -122.1329131},
#  {'displayName': 'Chipotle Mexican Grill',
#   'rating': 3.6,
#   'formattedAddress': '1328 156th Ave NE, Bellevue, WA 98007, USA',
#   'id': 'ChIJ8-2rhrptkFQRaPJt4Qp_d5I',
#   'latitude': 47.621616599999996,
#   'longitude': -122.13187889999999},
#  {'displayName': 'Nan Hot Pot',
#   'rating': 4.5,
#   'formattedAddress': '15600 NE 8th St Suite O18, Bellevue, WA 98008, USA',
#   'id': 'ChIJi_1LqIRtkFQR-2aTmtur8zw',
#   'latitude': 47.6208058,
#   'longitude': -122.1297756},
#  {'displayName': 'The French Bakery Crossroads Bellevue',
#   'rating': 4.1,
#   'formattedAddress': '15600 NE 8th St K-4, Bellevue, WA 98008, USA',
#   'id': 'ChIJz_B3r7ptkFQROmxRGhrbfbk',
#   'latitude': 47.6195375,
#   'longitude': -122.13112359999998},
#  {'displayName': 'JINYA Ramen Bar - Bellevue',
#   'rating': 4.3,
#   'formattedAddress': '15600 NE 8th St Suite 0-11, Bellevue, WA 98008, USA',
#   'id': 'ChIJN6THkLptkFQR0PMowKglf78',
#   'latitude': 47.6207918,
#   'longitude': -122.13041330000001},
#  {'displayName': 'Tutta Bella Neapolitan Pizzeria',
#   'rating': 4.2,
#   'formattedAddress': '15600 NE 8th St Suite J1, Bellevue, WA 98008, USA',
#   'id': 'ChIJ34awiLBtkFQRyOr9oKtXS58',
#   'latitude': 47.6191788,
#   'longitude': -122.13098910000001},
#  {'displayName': 'Starbucks',
#   'rating': 4.3,
#   'formattedAddress': '1350 156th Ave NE, Bellevue, WA 98007, USA',
#   'id': 'ChIJj_1WrbptkFQRLWA7-jut-cY',
#   'latitude': 47.6220661,
#   'longitude': -122.1319673},
#  {'displayName': 'Sushi Me',
#   'rating': 4.2,
#   'formattedAddress': '1299 156th Ave NE STE 145, Bellevue, WA 98007, USA',
#   'id': 'ChIJN8cpqLptkFQRF65T2iq5Qks',
#   'latitude': 47.6214016,
#   'longitude': -122.1327924},
#  {'displayName': 'Madhurai Mess',
#   'rating': 4,
#   'formattedAddress': '1424 156th Ave NE, Bellevue, WA 98007, USA',
#   'id': 'ChIJiRXr0CZtkFQRxlkUoMfgWRg',
#   'latitude': 47.6230518,
#   'longitude': -122.1320829},
#  {'displayName': 'Kwality Ice Cream Bellevue',
#   'rating': 4.2,
#   'formattedAddress': '1400 156th Ave NE, Bellevue, WA 98007, USA',
#   'id': 'ChIJYWiHGQhtkFQRhVWaSjSg71k',
#   'latitude': 47.6225696,
#   'longitude': -122.1320762},
#  {'displayName': 'Nai Brother Chinese Sauerkraut Fish',
#   'rating': 4.3,
#   'formattedAddress': '1299 156th Ave NE Ste 133, Bellevue, WA 98007, USA',
#   'id': 'ChIJ9XpRAEhtkFQRWQOhz616nWA',
#   'latitude': 47.6213282,
#   'longitude': -122.1331014},
#  {'displayName': 'Pizza Hut',
#   'rating': 3.7,
#   'formattedAddress': '15600 NE 8th St a-6, Bellevue, WA 98008, USA',
#   'id': 'ChIJF7_Ha-NtkFQRshb2JSDmsj4',
#   'latitude': 47.6173247,
#   'longitude': -122.1313113},
#  {'displayName': 'Mochinut',
#   'rating': 4.1,
#   'formattedAddress': '15600 NE 8th St, Bellevue, WA 98008, USA',
#   'id': 'ChIJId0Iyz5tkFQRNo-CTTXQBPY',
#   'latitude': 47.618893799999995,
#   'longitude': -122.13104550000001},
#  {'displayName': 'Ruchi Indian Restaurant',
#   'rating': 3.7,
#   'formattedAddress': '1360 156th Ave NE, Bellevue, WA 98007, USA',
#   'id': 'ChIJYSggTKVtkFQRMSttpBveGyI',
#   'latitude': 47.6223289,
#   'longitude': -122.13200219999999},
#  {'displayName': 'Starbucks',
#   'rating': 4,
#   'formattedAddress': '15600 NE 8th St, Bellevue, WA 98008, USA',
#   'id': 'ChIJOwOHkbBtkFQRvHXjdJeyYR4',
#   'latitude': 47.6172216,
#   'longitude': -122.1307624},
#  {'displayName': 'Bunsik',
#   'rating': 4.5,
#   'formattedAddress': '15600 NE 8th St suite o 16, Bellevue, WA 98008, USA',
#   'id': 'ChIJ-6hMFG1tkFQRRaQg-kHPP9U',
#   'latitude': 47.6208325,
#   'longitude': -122.1299319},
#  {'displayName': 'Palace Korean Bar & Grill',
#   'rating': 4,
#   'formattedAddress': 'Parking lot, 15932 NE 8th St, Bellevue, WA 98008, USA',
#   'id': 'ChIJLVdW_bltkFQRmF2obqKmMvc',
#   'latitude': 47.6173688,
#   'longitude': -122.1273197},
#  {'displayName': 'Hye Life Cafe & Bar',
#   'rating': 4.4,
#   'formattedAddress': '900 160th Ave NE Suite 1, Bellevue, WA 98008, USA',
#   'id': 'ChIJ4VMlse9tkFQR5YmWV4SOvnY',
#   'latitude': 47.61799190000001,
#   'longitude': -122.127242},
#  {'displayName': "Domino's Pizza",
#   'rating': 3.5,
#   'formattedAddress': '15920 NE 8th St Ste 5 Ste 5, Bellevue, WA 98008, USA',
#   'id': 'ChIJ5Sl-ULdtkFQR71hDYcTZcKI',
#   'latitude': 47.6174174,
#   'longitude': -122.1278639},
#  {'displayName': 'Sanyoung Surf & Turf BBQ 三羊开炭',
#   'rating': 4.6,
#   'formattedAddress': '15920 NE 8th St suite 2, Bellevue, WA 98008, USA',
#   'id': 'ChIJg3OShoRtkFQREV24bx6mp_o',
#   'latitude': 47.6175734,
#   'longitude': -122.12790869999999},
#  {'displayName': 'Joy Box Restaurant',
#   'rating': 4.1,
#   'formattedAddress': '15920 NE 8th St #1, Bellevue, WA 98008, USA',
#   'id': 'ChIJ3wyB0tptkFQRwcsSElPWzkY',
#   'latitude': 47.6176271,
#   'longitude': -122.1279096},
#  {'displayName': 'Antojitos Y Mas',
#   'rating': 4.1,
#   'formattedAddress': '16256 NE 8th St, Bellevue, WA 98008, USA',
#   'id': 'ChIJPZ3zBrltkFQRymj-Rl9B-Ts',
#   'latitude': 47.6171338,
#   'longitude': -122.1223534},
#  {'displayName': 'Churrascos La Esquina',
#   'rating': 4.1,
#   'formattedAddress': '900 160th Ave NE, Bellevue, WA 98008, USA',
#   'id': 'ChIJPyBiTt9tkFQRym3KQyZ_Wls',
#   'latitude': 47.6180686,
#   'longitude': -122.12796589999999},
#  {'displayName': 'Flavors of India',
#   'rating': -1,
#   'formattedAddress': '16000 NE 10th St, Bellevue, WA 98008, USA',
#   'id': 'ChIJAQDwarptkFQRCUTI-etb26A',
#   'latitude': 47.6193658,
#   'longitude': -122.1277828},
#  {'displayName': 'Empanadicious',
#   'rating': 5,
#   'formattedAddress': '900 160th Ave NE STE 3, Bellevue, WA 98008, USA',
#   'id': 'ChIJJwfd1AltkFQRTztW41_3nII',
#   'latitude': 47.61799190000001,
#   'longitude': -122.127242},
#  {'displayName': 'Looking for Chai Taiwanese Kitchen',
#   'rating': 4.4,
#   'formattedAddress': '12121 Northup Way #205, Bellevue, WA 98005, USA',
#   'id': 'ChIJq8KMPuVskFQRHt2uy0YCBQA',
#   'latitude': 47.6305932,
#   'longitude': -122.17905630000001},
#  {'displayName': 'Subway',
#   'rating': 3.9,
#   'formattedAddress': '12121 Northup Way #215, Bellevue, WA 98005, USA',
#   'id': 'ChIJTVulF-VskFQR6JN5QdVlo4c',
#   'latitude': 47.6300394,
#   'longitude': -122.17837069999999},
#  {'displayName': 'Mercurys Coffee Co.',
#   'rating': 4.4,
#   'formattedAddress': '13102 NE 20th St, Bellevue, WA 98005, USA',
#   'id': 'ChIJwXyjgP5skFQRbKQjyqmj2qs',
#   'latitude': 47.628321,
#   'longitude': -122.16556600000001},
#  {'displayName': 'Cascadia Pizza Restaurant and Brewery',
#   'rating': 4.8,
#   'formattedAddress': '1820 130th Ave NE Suite 2, Bellevue, WA 98005, USA',
#   'id': 'ChIJL3LXNa5tkFQRBDUFokv1kC0',
#   'latitude': 47.6266022,
#   'longitude': -122.16617579999998},
#  {'displayName': 'Dan Gui Sichuan Cuisine',
#   'rating': 4.2,
#   'formattedAddress': '13112 NE 20th St, Bellevue, WA 98005, USA',
#   'id': 'ChIJN5sDHzZtkFQRKM7mhv3SE-s',
#   'latitude': 47.628839199999994,
#   'longitude': -122.16567339999999},
#  {'displayName': 'Royal Kitchen',
#   'rating': 3.8,
#   'formattedAddress': '13200 NE 20th St Ste 400, Bellevue, WA 98005, USA',
#   'id': 'ChIJcf9Cfv5skFQRzaQYxfRR280',
#   'latitude': 47.6284831,
#   'longitude': -122.16427440000001},
#  {'displayName': "Angelo's of Bellevue",
#   'rating': 4.4,
#   'formattedAddress': '1830 130th Ave NE, Bellevue, WA 98005, USA',
#   'id': 'ChIJuxQ7sv5skFQRaocSrE5W6GM',
#   'latitude': 47.6269302,
#   'longitude': -122.1665802},
#  {'displayName': 'Shahana Steakhouse (Burger n Gyros)',
#   'rating': 4.5,
#   'formattedAddress': '2285 140th Ave NE, Bellevue, WA 98005, USA',
#   'id': 'ChIJBX3qd7JykFQRC7Wd_Ob5yJU',
#   'latitude': 47.630133099999995,
#   'longitude': -122.15596860000001},
#  {'displayName': 'Papa Johns Pizza',
#   'rating': 3.8,
#   'formattedAddress': '13600 NE 20th St, Bellevue, WA 98005, USA',
#   'id': 'ChIJ1xgOmY9skFQRsB3MNyS4K9s',
#   'latitude': 47.6282211,
#   'longitude': -122.15890379999998},
#  {'displayName': 'Ramen Nori',
#   'rating': 4.7,
#   'formattedAddress': '13112 NE 20th St #200, Bellevue, WA 98005, USA',
#   'id': 'ChIJuUA3NI5tkFQRTx_4QUqxey4',
#   'latitude': 47.628839199999994,
#   'longitude': -122.16567339999999},
#  {'displayName': 'Caspian Bellevue',
#   'rating': 4,
#   'formattedAddress': '1806 136th Pl NE, Bellevue, WA 98005, USA',
#   'id': 'ChIJJ0ipIABtkFQR393hjooyMxw',
#   'latitude': 47.6263037,
#   'longitude': -122.1569432},
#  {'displayName': 'Chili Master 湘巴佬',
#   'rating': 4.9,
#   'formattedAddress': '13433 NE 20th St Suite A, Bellevue, WA 98005, USA',
#   'id': 'ChIJ4ReKuGFtkFQRhDi-TB_QkE8',
#   'latitude': 47.627702899999996,
#   'longitude': -122.15987580000001},
#  {'displayName': "Sugee's Box Lunch Company",
#   'rating': 4.7,
#   'formattedAddress': '13225 NE 20th St, Bellevue, WA 98005, USA',
#   'id': 'ChIJM4HxbP5skFQRs_moazE50ZE',
#   'latitude': 47.6270622,
#   'longitude': -122.1626337},
#  {'displayName': 'ampm',
#   'rating': 2,
#   'formattedAddress': '12903 NE 20th St, Bellevue, WA 98005, USA',
#   'id': 'ChIJUxhTEPxskFQR9VCHYyIBs-8',
#   'latitude': 47.6276757,
#   'longitude': -122.16788509999999},
#  {'displayName': 'DongBei Harvest 东北人家',
#   'rating': 4,
#   'formattedAddress': '13433 NE 20th St G, Bellevue, WA 98005, USA',
#   'id': 'ChIJMdMJg1xtkFQRL1Yya5o0rNE',
#   'latitude': 47.627721199999996,
#   'longitude': -122.1601626},
#  {'displayName': 'Kin Dee Bellevue',
#   'rating': 4.9,
#   'formattedAddress': '13238 NE 20th St Suite 100, Bellevue, WA 98005, USA',
#   'id': 'ChIJizpdHRptkFQREzbGlJ7pvic',
#   'latitude': 47.628524399999996,
#   'longitude': -122.16394950000002},
#  {'displayName': 'Market Seoul',
#   'rating': -1,
#   'formattedAddress': '13622 NE 20th St Suite D, Bellevue, WA 98005, USA',
#   'id': 'ChIJRemB2kJtkFQRMDLps8NIzes',
#   'latitude': 47.6283482,
#   'longitude': -122.1579075},
#  {'displayName': 'Honest Restaurant',
#   'rating': 3.8,
#   'formattedAddress': '2241 148th Ave NE, Bellevue, WA 98007, USA',
#   'id': 'ChIJQQOEpfptkFQR88IiUF_6EnI',
#   'latitude': 47.6306838,
#   'longitude': -122.1451578},
#  {'displayName': 'MTR - Mavalli Tiffin Rooms',
#   'rating': 3.5,
#   'formattedAddress': '14625 NE 24th St Suite 3, Bellevue, WA 98007, USA',
#   'id': 'ChIJKdbZe1NtkFQRriv_LggP-Io',
#   'latitude': 47.6310207,
#   'longitude': -122.14488300000001},
#  {'displayName': "McDonald's",
#   'rating': 3.7,
#   'formattedAddress': '13841 NE 20th St, Bellevue, WA 98005, USA',
#   'id': 'ChIJPfieWABtkFQRmHQ_Cg8SOdQ',
#   'latitude': 47.6275603,
#   'longitude': -122.15459860000001},
#  {'displayName': '85°C Bakery Cafe - Bellevue',
#   'rating': 4,
#   'formattedAddress': '14701 NE 20th St, Bellevue, WA 98007, USA',
#   'id': 'ChIJVRQbBtBtkFQRR8rlQ6SWfBY',
#   'latitude': 47.627645699999995,
#   'longitude': -122.14443969999999},
#  {'displayName': 'Supreme Dumplings',
#   'rating': 4.6,
#   'formattedAddress': '14603 NE 20th St #4B, Bellevue, WA 98007, USA',
#   'id': 'ChIJ_fbAUWVtkFQRqLBlBvTTYVA',
#   'latitude': 47.6267547,
#   'longitude': -122.1450034},
#  {'displayName': 'Shaoshan Impression',
#   'rating': 4.2,
#   'formattedAddress': '14150 NE 20th St Ste C, Bellevue, WA 98007, USA',
#   'id': 'ChIJyzE8HEFtkFQRqlFSu2PzSns',
#   'latitude': 47.628349299999996,
#   'longitude': -122.15152499999998},
#  {'displayName': 'Chaat House',
#   'rating': 4,
#   'formattedAddress': '14725 NE 20th St, Bellevue, WA 98007, USA',
#   'id': 'ChIJw1PmRahtkFQRf1A2-8KFbAY',
#   'latitude': 47.6275173,
#   'longitude': -122.14375309999998},
#  {'displayName': 'Taco Bell',
#   'rating': 3.8,
#   'formattedAddress': '1960 148th Ave NE, Redmond, WA 98052, USA',
#   'id': 'ChIJUTI-XahtkFQRinovfbInDV4',
#   'latitude': 47.6274581,
#   'longitude': -122.1427305},
#  {'displayName': 'Sun Sui Wah Seafood Restaurant',
#   'rating': 3.4,
#   'formattedAddress': '14505 NE 20th St Suite R, Bellevue, WA 98007, USA',
#   'id': 'ChIJrRoYbABtkFQRuO9YVfx_DDc',
#   'latitude': 47.627480500000004,
#   'longitude': -122.1465107},
#  {'displayName': 'IHOP',
#   'rating': 4.1,
#   'formattedAddress': '14747 NE 20th St, Bellevue, WA 98007, USA',
#   'id': 'ChIJ1bG5UahtkFQRlt8q4CaRUwU',
#   'latitude': 47.627114899999995,
#   'longitude': -122.143647},
#  {'displayName': 'Núodle',
#   'rating': 3.9,
#   'formattedAddress': '14603 NE 20th St #6, Bellevue, WA 98007, USA',
#   'id': 'ChIJsUFKrKltkFQRIknWBbPUeio',
#   'latitude': 47.626832199999996,
#   'longitude': -122.1445249},
#  {'displayName': 'Gyu-Kaku Japanese BBQ',
#   'rating': 4.2,
#   'formattedAddress': '14506 NE 20th St #2, Bellevue, WA 98007, USA',
#   'id': 'ChIJEXqrKqhtkFQRe2Xie0--puE',
#   'latitude': 47.628195299999994,
#   'longitude': -122.14614630000001},
#  {'displayName': 'Rasoi Indian Restaurant and Bakery',
#   'rating': 4.4,
#   'formattedAddress': '14339 NE 20th St Ste I, Bellevue, WA 98007, USA',
#   'id': 'ChIJJ6v8Vm5tkFQRqZLWQZLFw38',
#   'latitude': 47.6271363,
#   'longitude': -122.1489197},
#  {'displayName': 'Anjappar Seattle Indian Restaurant',
#   'rating': 3.7,
#   'formattedAddress': '14625 NE 24th St, Bellevue, WA 98007, USA',
#   'id': 'ChIJiy0l1wdtkFQR59HQyOyqv4A',
#   'latitude': 47.6311586,
#   'longitude': -122.14517609999999},
#  {'displayName': 'Frying Fish',
#   'rating': 4.4,
#   'formattedAddress': '1915 140th Ave NE #2347, Bellevue, WA 98005, USA',
#   'id': 'ChIJHRQNBxhskFQRbIgH4Gh28ic',
#   'latitude': 47.627047700000006,
#   'longitude': -122.1543171},
#  {'displayName': 'Liuyishou Hotpot',
#   'rating': 4.4,
#   'formattedAddress': '1644 140th Ave NE, Bellevue, WA 98005, USA',
#   'id': 'ChIJF6Q8F_FtkFQRVSNnJdLAsyQ',
#   'latitude': 47.625420399999996,
#   'longitude': -122.15314140000001},
#  {'displayName': 'Dough Zone Dumpling House Overlake',
#   'rating': 4.4,
#   'formattedAddress': '14625 NE 24th St #4b, Bellevue, WA 98007, USA',
#   'id': 'ChIJh0ZU1gdtkFQRhRYYEFQaNb0',
#   'latitude': 47.6311077,
#   'longitude': -122.1449732},
#  {'displayName': 'MonGa Café',
#   'rating': 4.2,
#   'formattedAddress': '14603 NE 20th St, Bellevue, WA 98007, USA',
#   'id': 'ChIJ84WEpaltkFQRh3HXheNKzns',
#   'latitude': 47.626871099999995,
#   'longitude': -122.1452053},
#  {'displayName': 'Timeless Tea (Bellevue)',
#   'rating': 4.2,
#   'formattedAddress': '14320 NE 20th St ste d, Bellevue, WA 98007, USA',
#   'id': 'ChIJl3AxSdhtkFQRflGKXUZHNNA',
#   'latitude': 47.6282278,
#   'longitude': -122.1493253},
#  {'displayName': 'Donburi Station Bellevue',
#   'rating': 4.4,
#   'formattedAddress': '14339 NE 20th St Ste E, Bellevue, WA 98007, USA',
#   'id': 'ChIJLdjYX59tkFQRud31PPNm9S4',
#   'latitude': 47.627410999999995,
#   'longitude': -122.149031},
#  {'displayName': 'Dosa House',
#   'rating': 4,
#   'formattedAddress': '15259 NE Bel Red Rd, Bellevue, WA 98007, USA',
#   'id': 'ChIJse098aZtkFQRjiy3Fe1l8Zw',
#   'latitude': 47.6281877,
#   'longitude': -122.1355835},
#  {'displayName': 'Can Am Pizza',
#   'rating': 4.2,
#   'formattedAddress': '2125 NE Bel Red Rd, Redmond, WA 98052, USA',
#   'id': 'ChIJ88D0631skFQR15tP90fZ2no',
#   'latitude': 47.6295645,
#   'longitude': -122.13527230000001},
#  {'displayName': "Jack's BBQ & Steakhouse Bellevue | Redmond",
#   'rating': 4.3,
#   'formattedAddress': '2115 NE Bel Red Rd, Redmond, WA 98052, USA',
#   'id': 'ChIJKRdqeABtkFQRtkeBB7rhLFY',
#   'latitude': 47.6292817,
#   'longitude': -122.13561919999998},
#  {'displayName': 'Shinya Shokudō',
#   'rating': 4.4,
#   'formattedAddress': '2020 148th Ave NE, Redmond, WA 98052, USA',
#   'id': 'ChIJE6GJWNhtkFQRBsJJei6xsig',
#   'latitude': 47.6281915,
#   'longitude': -122.1411625},
#  {'displayName': 'Mediterranean Grill',
#   'rating': 4.3,
#   'formattedAddress': '15253 NE Bel Red Rd, Bellevue, WA 98007, USA',
#   'id': 'ChIJr6ZQ5qZtkFQRSkspoPABooE',
#   'latitude': 47.628699999999995,
#   'longitude': -122.135027},
#  {'displayName': 'Tapioca Express',
#   'rating': 3.9,
#   'formattedAddress': '15230 NE 24th St, Redmond, WA 98052, USA',
#   'id': 'ChIJE4jaAAptkFQRSWhnmn8JNb8',
#   'latitude': 47.631983700000006,
#   'longitude': -122.13586509999999},
#  {'displayName': "Arby's",
#   'rating': 4,
#   'formattedAddress': '15115 NE 24th St, Redmond, WA 98052, USA',
#   'id': 'ChIJmRG62gltkFQRM6oEgTXaX1k',
#   'latitude': 47.6313223,
#   'longitude': -122.1390156},
#  {'displayName': 'Crimson Coward',
#   'rating': 4,
#   'formattedAddress': '2028 148th Ave NE, Redmond, WA 98052, USA',
#   'id': 'ChIJ0xbF0h9tkFQRKa1fET3rg_c',
#   'latitude': 47.6282066,
#   'longitude': -122.14142179999999},
#  {'displayName': 'Foody moody halal Indian Pakistani cuisine',
#   'rating': 4.8,
#   'formattedAddress': '2444 NE Bel Red Rd, Bellevue, WA 98007, USA',
#   'id': 'ChIJE0w6f3lDkFQRIkEnaMQLg4c',
#   'latitude': 47.6319169,
#   'longitude': -122.13294359999998},
#  {'displayName': 'Pagliacci Pizza',
#   'rating': 4.5,
#   'formattedAddress': '15238 NE Bel Red Rd, Bellevue, WA 98007, USA',
#   'id': 'ChIJRZe_V6ZtkFQRpe6nTXrxOUo',
#   'latitude': 47.628109,
#   'longitude': -122.135945},
#  {'displayName': 'Tian Tian Noodles',
#   'rating': 4,
#   'formattedAddress': '15230 NE 24th St, Redmond, WA 98052, USA',
#   'id': 'ChIJTwRoAgptkFQRFFQni1gG8qs',
#   'latitude': 47.631916399999994,
#   'longitude': -122.1359298},
#  {'displayName': 'El Maestro del Taco',
#   'rating': 4.7,
#   'formattedAddress': '1836 156th Ave NE, Bellevue, WA 98007, USA',
#   'id': 'ChIJcw9b0rZtkFQREINY01y7mME',
#   'latitude': 47.626999399999995,
#   'longitude': -122.1306505},
#  {'displayName': 'Sukhothai Restaurant',
#   'rating': 4.3,
#   'formattedAddress': '15045 NE Bel Red Rd, Bellevue, WA 98007, USA',
#   'id': 'ChIJHYF1PKZtkFQRIewG3ZWWSzM',
#   'latitude': 47.6272927,
#   'longitude': -122.13832470000001},
#  {'displayName': '7-Eleven',
#   'rating': 2.2,
#   'formattedAddress': '15521 NE Bel Red Rd, Bellevue, WA 98007, USA',
#   'id': 'ChIJkzR1maBtkFQRS_b_zXMpay0',
#   'latitude': 47.631827699999995,
#   'longitude': -122.13329729999998},
#  {'displayName': 'Potbelly Sandwich Shop',
#   'rating': 4,
#   'formattedAddress': '15425 NE 24th St, Bellevue, WA 98007, USA',
#   'id': 'ChIJZXfheSdskFQRicl8XRZe_d0',
#   'latitude': 47.630731399999995,
#   'longitude': -122.13403129999999},
#  {'displayName': 'Teapot Vegetarian House',
#   'rating': 4.2,
#   'formattedAddress': '15230 NE 24th St Ste H, Redmond, WA 98052, USA',
#   'id': 'ChIJE4jaAAptkFQRCeka4cpRkOI',
#   'latitude': 47.631927399999995,
#   'longitude': -122.13665999999998},
#  {'displayName': "Miah's Kitchen",
#   'rating': 4,
#   'formattedAddress': '2022 148th Ave NE #13b, Redmond, WA 98052, USA',
#   'id': 'ChIJZ_AWgX93CEERlF5MCNVchOY',
#   'latitude': 47.6282,
#   'longitude': -122.14127780000001},
#  {'displayName': "Jimmy John's",
#   'rating': 3.5,
#   'formattedAddress': '15253 NE Bel Red Rd, Bellevue, WA 98007, USA',
#   'id': 'ChIJDz_l5aZtkFQR0JxWrMJJlF8',
#   'latitude': 47.6286077,
#   'longitude': -122.13509940000002},
#  {'displayName': 'La Tía Angelina',
#   'rating': 4.5,
#   'formattedAddress': '2444 NE Bel Red Rd, Redmond, WA 98052, USA',
#   'id': 'ChIJR4_zXR9tkFQRR7gn-iENrC8',
#   'latitude': 47.6319169,
#   'longitude': -122.13294359999998},
#  {'displayName': 'Depot Point',
#   'rating': -1,
#   'formattedAddress': '2018 156th Ave NE, Bellevue, WA 98007, USA',
#   'id': 'ChIJ5cWDaKFtkFQRgqjPMA-3sI0',
#   'latitude': 47.629002199999995,
#   'longitude': -122.1299993}]

# %%
print(f"Got {len(all_places)} places:")
for place in sorted(all_places, key=lambda p: p.get("rating", -1), reverse=True):
    name = place.get('displayName')
    rating = place.get("rating", "N/A")
    print(f" - {name} ({rating})")
# Out:
# Got 192 places:
#  - Evergreen Point Bistro (5)
#  - Lunch on the Plate (5)
#  - STALLION (5)
#  - GREEN APPLE DELI-(Spring Deli) (5)
#  - Empanadicious (5)
#  - Naturalz Ice Cream (4.9)
#  - Sammy’s Food Truck (4.9)
#  - Master Bing (Bellevue) 煎饼师傅 (4.9)
#  - Chili Master 湘巴佬 (4.9)
#  - Kin Dee Bellevue (4.9)
#  - La Chingona Mexican Cuisine Bellevue (4.8)
#  - Pasifika Grill & Bar (4.8)
#  - Cascadia Pizza Restaurant and Brewery (4.8)
#  - Foody moody halal Indian Pakistani cuisine (4.8)
#  - TRES Sandwich (4.7)
#  - Haidilao Hot Pot Bellevue (4.7)
#  - O'Bop (4.7)
#  - Mox Boarding House (4.7)
#  - Ramen Nori (4.7)
#  - Sugee's Box Lunch Company (4.7)
#  - El Maestro del Taco (4.7)
#  - Fogo de Chão Brazilian Steakhouse (4.6)
#  - La Mar Cocina Peruana Bellevue (4.6)
#  - JOEY Bellevue (4.6)
#  - STK Steakhouse (4.6)
#  - Sanyoung Surf & Turf BBQ 三羊开炭 (4.6)
#  - Supreme Dumplings (4.6)
#  - Tokyo Stop Teriyaki (4.5)
#  - Tendon Kohaku (4.5)
#  - Lincoln Square South (4.5)
#  - Carmine's (4.5)
#  - Cinemark Reserve Lincoln Square — Dine-In 21+ (4.5)
#  - Seastar Restaurant & Raw Bar (4.5)
#  - Araya's Place Vegan Thai Bellevue (4.5)
#  - Kizuki Ramen & Izakaya (4.5)
#  - Din Tai Fung 鼎泰豐 (4.5)
#  - Duke’s Seafood Bellevue (4.5)
#  - The Pumphouse Bar & Grill (4.5)
#  - John Howie Steak (4.5)
#  - Bellevue Brewing Company - Spring District Brewpub (4.5)
#  - Los Chilangos - Bellevue (4.5)
#  - Nan Hot Pot (4.5)
#  - Bunsik (4.5)
#  - Shahana Steakhouse (Burger n Gyros) (4.5)
#  - Pagliacci Pizza (4.5)
#  - La Tía Angelina (4.5)
#  - Dilettante Mocha Café at Bellefield Office Park (4.4)
#  - Shabu Shabu Kyoto (4.4)
#  - BRUNCHBAR (4.4)
#  - Hokkaido Ramen Santouka Bellevue (4.4)
#  - Lao Ma Tou Hot Pot 老码头火锅 (4.4)
#  - 520 Bar & Grill (4.4)
#  - Cactus Bellevue Square (4.4)
#  - Japonessa Sushi Cocina (4.4)
#  - Cielo Cocina Mexicana (4.4)
#  - Woobling Korean BBQ (4.4)
#  - I Love Sushi on Lake Bellevue (4.4)
#  - Wild Wasabi Signature (4.4)
#  - Dick's Drive-In (4.4)
#  - Happy Lamb Hot Pot (4.4)
#  - Banaras (4.4)
#  - Hye Life Cafe & Bar (4.4)
#  - Looking for Chai Taiwanese Kitchen (4.4)
#  - Mercurys Coffee Co. (4.4)
#  - Angelo's of Bellevue (4.4)
#  - Rasoi Indian Restaurant and Bakery (4.4)
#  - Frying Fish (4.4)
#  - Liuyishou Hotpot (4.4)
#  - Dough Zone Dumpling House Overlake (4.4)
#  - Donburi Station Bellevue (4.4)
#  - Shinya Shokudō (4.4)
#  - Ascend Prime Steak & Sushi (4.3)
#  - Nana’s Green Tea (4.3)
#  - Desi Tadka Indian Grill (4.3)
#  - Monsoon Bellevue (4.3)
#  - Bellden Cafe (4.3)
#  - Best Wok Restaurant (4.3)
#  - Greek Express (4.3)
#  - Menchie's Frozen Yogurt (4.3)
#  - Earls Kitchen + Bar (4.3)
#  - Tavern Hall (4.3)
#  - Cafe Hagen (Modern Scandinavian All Day Restaurant and Cocktail Bar) (4.3)
#  - Chick-fil-A (4.3)
#  - Farine Bakery & Café (4.3)
#  - Tanoor Bellevue (4.3)
#  - Minamoto Japanese Cuisine (4.3)
#  - Andiamo Italian Ristorante (4.3)
#  - Facing East | Taiwanese Restaurant (4.3)
#  - JINYA Ramen Bar - Bellevue (4.3)
#  - Starbucks (4.3)
#  - Nai Brother Chinese Sauerkraut Fish (4.3)
#  - Jack's BBQ & Steakhouse Bellevue | Redmond (4.3)
#  - Mediterranean Grill (4.3)
#  - Sukhothai Restaurant (4.3)
#  - Jayam's Tiffins and Thali (4.2)
#  - Fern Thai on Main (Bellevue) (4.2)
#  - Dough Zone Dumpling House Bellevue (4.2)
#  - Kura Revolving Sushi Bar (4.2)
#  - Poppinjay's A Cafe (4.2)
#  - Cinemark Lincoln Square Cinemas and IMAX (4.2)
#  - Kobe Bellevue Restaurant (4.2)
#  - Cafe Joy (4.2)
#  - The Goose Pub & Eatery (4.2)
#  - Tutta Bella Neapolitan Pizzeria (4.2)
#  - Sushi Me (4.2)
#  - Kwality Ice Cream Bellevue (4.2)
#  - Dan Gui Sichuan Cuisine (4.2)
#  - Shaoshan Impression (4.2)
#  - Gyu-Kaku Japanese BBQ (4.2)
#  - MonGa Café (4.2)
#  - Timeless Tea (Bellevue) (4.2)
#  - Can Am Pizza (4.2)
#  - Teapot Vegetarian House (4.2)
#  - Rivue Bar and Grill (4.1)
#  - Papa Murphy's | Take 'N' Bake Pizza (4.1)
#  - YGF MaLaTang Bellevue (4.1)
#  - Starbucks (4.1)
#  - The Cheesecake Factory (4.1)
#  - Inchin's Bamboo Garden (4.1)
#  - Wild Ginger Bellevue (4.1)
#  - Cantina Monarca (4.1)
#  - Castilla Restaurant and Tapas Bar (4.1)
#  - Chutneys Bellevue (4.1)
#  - Starbucks (4.1)
#  - Phở Ever (4.1)
#  - Spring Deli & Market/Greenapple Deli (4.1)
#  - Tasty Szechuan (4.1)
#  - The French Bakery Crossroads Bellevue (4.1)
#  - Mochinut (4.1)
#  - Joy Box Restaurant (4.1)
#  - Antojitos Y Mas (4.1)
#  - Churrascos La Esquina (4.1)
#  - IHOP (4.1)
#  - Dave & Buster's Bellevue (4)
#  - Boiling Point (4)
#  - The French Bakery (4)
#  - Ten Seconds Yunnan Rice Noodle (4)
#  - Madhurai Mess (4)
#  - Starbucks (4)
#  - Palace Korean Bar & Grill (4)
#  - Caspian Bellevue (4)
#  - DongBei Harvest 东北人家 (4)
#  - 85°C Bakery Cafe - Bellevue (4)
#  - Chaat House (4)
#  - Dosa House (4)
#  - Arby's (4)
#  - Crimson Coward (4)
#  - Tian Tian Noodles (4)
#  - Potbelly Sandwich Shop (4)
#  - Miah's Kitchen (4)
#  - Malay Satay Hut (3.9)
#  - Panera Bread (3.9)
#  - Farzi Café (3.9)
#  - The Crab Pot Bellevue (3.9)
#  - Subway (3.9)
#  - Núodle (3.9)
#  - Tapioca Express (3.9)
#  - IFB Market (3.8)
#  - Chipotle Mexican Grill (3.8)
#  - Solarium Kitchen & Bar (3.8)
#  - Royal Kitchen (3.8)
#  - Papa Johns Pizza (3.8)
#  - Honest Restaurant (3.8)
#  - Taco Bell (3.8)
#  - Polaris Restaurant (3.7)
#  - Wingstop (3.7)
#  - Pizza Hut (3.7)
#  - Ruchi Indian Restaurant (3.7)
#  - McDonald's (3.7)
#  - Anjappar Seattle Indian Restaurant (3.7)
#  - Lin Handmade Dumplings (3.6)
#  - Wendy's (3.6)
#  - Shake Shack Bellevue Square (3.6)
#  - McDonald's (3.6)
#  - Chipotle Mexican Grill (3.6)
#  - Domino's Pizza (3.5)
#  - MTR - Mavalli Tiffin Rooms (3.5)
#  - Jimmy John's (3.5)
#  - Chipotle Mexican Grill (3.4)
#  - Sun Sui Wah Seafood Restaurant (3.4)
#  - Amuse Bar + Restaurant (3.2)
#  - Burger King (3.2)
#  - Tacos Paraíso (3)
#  - Hot Ones™ by The Goose Pub & Eatery (3)
#  - 7-Eleven (2.8)
#  - Shell (2.6)
#  - ampm (2.6)
#  - 7-Eleven (2.2)
#  - ampm (2)
#  - Flavors of India (-1)
#  - Market Seoul (-1)
#  - Depot Point (-1)

# %%
all_places
# Out:
# [{'displayName': 'Dilettante Mocha Café at Bellefield Office Park',
#   'rating': 4.4,
#   'formattedAddress': 'Bellefield Office Park, Conifer Building, 1450 114th Ave SE #120, Bellevue, WA 98004, USA',
#   'id': 'ChIJUaS2CnRskFQRgkVy8FFKcKE',
#   'latitude': 47.597937099999996,
#   'longitude': -122.18787809999999},
#  {'displayName': 'Polaris Restaurant',
#   'rating': 3.7,
#   'formattedAddress': '11200 SE 6th St, Bellevue, WA 98004, USA',
#   'id': 'ChIJtToSvHpskFQR9plO2_RX048',
#   'latitude': 47.605349499999996,
#   'longitude': -122.1895634},
#  {'displayName': 'Rivue Bar and Grill',
#   'rating': 4.1,
#   'formattedAddress': '605 114th Ave SE, Bellevue, WA 98004, USA',
#   'id': 'ChIJAy-pHnBskFQRYYC9N_vXHLo',
#   'latitude': 47.6039125,
#   'longitude': -122.1864034},
#  {'displayName': 'TRES Sandwich',
#   'rating': 4.7,
#   'formattedAddress': '1502 145th Pl SE, Bellevue, WA 98007, USA',
#   'id': 'ChIJwTsohjxskFQRZTRFHsbBl1o',
#   'latitude': 47.5969828,
#   'longitude': -122.15012670000002},
#  {'displayName': 'Tokyo Stop Teriyaki',
#   'rating': 4.5,
#   'formattedAddress': '1504 145th Pl SE, Bellevue, WA 98007, USA',
#   'id': 'ChIJy59LiTxskFQRDfTH40WrfvU',
#   'latitude': 47.5970278,
#   'longitude': -122.1498502},
#  {'displayName': "Papa Murphy's | Take 'N' Bake Pizza",
#   'rating': 4.1,
#   'formattedAddress': 'next to QFC, 1500 145th Pl SE Suite 4, Bellevue, WA 98007, USA',
#   'id': 'ChIJYbU_RjNskFQRYwg0qDUEi08',
#   'latitude': 47.5969759,
#   'longitude': -122.14977160000001},
#  {'displayName': 'Tacos Paraíso',
#   'rating': 3,
#   'formattedAddress': '903 142nd Ave SE, Bellevue, WA 98007, USA',
#   'id': 'ChIJy_vSFkJtkFQR4bNxqtk6-w4',
#   'latitude': 47.602038199999996,
#   'longitude': -122.15105620000001},
#  {'displayName': 'YGF MaLaTang Bellevue',
#   'rating': 4.1,
#   'formattedAddress': '683 156th Ave SE, Bellevue, WA 98007, USA',
#   'id': 'ChIJXdThK_ptkFQRxsxeH_wkqws',
#   'latitude': 47.6040978,
#   'longitude': -122.13271249999998},
#  {'displayName': "Jayam's Tiffins and Thali",
#   'rating': 4.2,
#   'formattedAddress': '15546 Lake Hills Blvd, Bellevue, WA 98007, USA',
#   'id': 'ChIJhYTLWGRtkFQR1kOOMKewGJM',
#   'latitude': 47.6035652,
#   'longitude': -122.13231789999999},
#  {'displayName': 'IFB Market',
#   'rating': 3.8,
#   'formattedAddress': '655 156th Ave SE Suite A103, Bellevue, WA 98007, USA',
#   'id': 'ChIJHwWvUaVtkFQRef7hKkN7r9w',
#   'latitude': 47.6038218,
#   'longitude': -122.13161500000001},
#  {'displayName': 'Malay Satay Hut',
#   'rating': 3.9,
#   'formattedAddress': '667 156th Ave SE, Bellevue, WA 98007, USA',
#   'id': 'ChIJE4jaAAptkFQRemASJ3WrBg4',
#   'latitude': 47.6043087,
#   'longitude': -122.13274669999998},
#  {'displayName': 'Shabu Shabu Kyoto',
#   'rating': 4.4,
#   'formattedAddress': '627 156th Ave SE, Bellevue, WA 98007, USA',
#   'id': 'ChIJOYOFQjNskFQRQvaNYdeXpLk',
#   'latitude': 47.604612499999995,
#   'longitude': -122.132511},
#  {'displayName': 'Naturalz Ice Cream',
#   'rating': 4.9,
#   'formattedAddress': '655 156th Ave SE Suite A108, Bellevue, WA 98007, USA',
#   'id': 'ChIJaTpiqDdtkFQRyS_4lTmp9G8',
#   'latitude': 47.604156599999996,
#   'longitude': -122.13176729999999},
#  {'displayName': 'BRUNCHBAR',
#   'rating': 4.4,
#   'formattedAddress': '623 156th Ave SE, Bellevue, WA 98007, USA',
#   'id': 'ChIJP6-XNg1tkFQRQI6F7ENuOqY',
#   'latitude': 47.6046388,
#   'longitude': -122.132288},
#  {'displayName': 'Lin Handmade Dumplings',
#   'rating': 3.6,
#   'formattedAddress': '677 156th Ave SE, Bellevue, WA 98007, USA',
#   'id': 'ChIJszruQABtkFQR0pcHTYqk8QE',
#   'latitude': 47.6041729,
#   'longitude': -122.1326407},
#  {'displayName': 'Sammy’s Food Truck',
#   'rating': 4.9,
#   'formattedAddress': '15231 Lake Hills Blvd, Bellevue, WA 98007, USA',
#   'id': 'ChIJBakmJwBtkFQRLpGIA33WIIQ',
#   'latitude': 47.602325699999994,
#   'longitude': -122.1359451},
#  {'displayName': 'Tendon Kohaku',
#   'rating': 4.5,
#   'formattedAddress': '233 106th Ave NE, Bellevue, WA 98004, USA',
#   'id': 'ChIJ6R7bJwBtkFQR-XiMLLqDGME',
#   'latitude': 47.6129752,
#   'longitude': -122.19923860000002},
#  {'displayName': 'Haidilao Hot Pot Bellevue',
#   'rating': 4.7,
#   'formattedAddress': '188 106th Ave NE Suite #210, Bellevue, WA 98004, USA',
#   'id': 'ChIJR7EsrcptkFQRvBHLTDOJnaQ',
#   'latitude': 47.61179490000001,
#   'longitude': -122.19838480000001},
#  {'displayName': 'Fogo de Chão Brazilian Steakhouse',
#   'rating': 4.6,
#   'formattedAddress': '440 Bellevue Way NE, Bellevue, WA 98004, USA',
#   'id': 'ChIJSd2HOYZskFQRkOESY01_MM0',
#   'latitude': 47.6145342,
#   'longitude': -122.20127389999999},
#  {'displayName': 'Ascend Prime Steak & Sushi',
#   'rating': 4.3,
#   'formattedAddress': '10400 NE 4th St Ste 3100, Bellevue, WA 98004, USA',
#   'id': 'ChIJN6EN0whtkFQR1lYGeflDEFc',
#   'latitude': 47.6142129,
#   'longitude': -122.20077119999999},
#  {'displayName': 'Nana’s Green Tea',
#   'rating': 4.3,
#   'formattedAddress': '16 103rd Ave NE, Bellevue, WA 98004, USA',
#   'id': 'ChIJeahpu0ltkFQRItNlPE0Wslc',
#   'latitude': 47.6106023,
#   'longitude': -122.2026693},
#  {'displayName': 'Hokkaido Ramen Santouka Bellevue',
#   'rating': 4.4,
#   'formattedAddress': '3rd, 103 Bellevue Way NE Suite 3, Bellevue, WA 98004, USA',
#   'id': 'ChIJTaRy231skFQRF8u2jBrpyl4',
#   'latitude': 47.6113247,
#   'longitude': -122.2020972},
#  {'displayName': 'Lincoln Square South',
#   'rating': 4.5,
#   'formattedAddress': '500 Bellevue Way NE, Bellevue, WA 98004, USA',
#   'id': 'ChIJG586rIhskFQROohpT2geS10',
#   'latitude': 47.6142475,
#   'longitude': -122.2007738},
#  {'displayName': 'Fern Thai on Main (Bellevue)',
#   'rating': 4.2,
#   'formattedAddress': '10134 Main St, Bellevue, WA 98004, USA',
#   'id': 'ChIJQX7ANqFtkFQRmfzOyNMLa4U',
#   'latitude': 47.61036550000001,
#   'longitude': -122.2046284},
#  {'displayName': "Carmine's",
#   'rating': 4.5,
#   'formattedAddress': '88 102nd Ave NE, Bellevue, WA 98004, USA',
#   'id': 'ChIJtaDvTYdskFQRPFeF4DNV3pg',
#   'latitude': 47.611089799999995,
#   'longitude': -122.20387880000001},
#  {'displayName': 'Dough Zone Dumpling House Bellevue',
#   'rating': 4.2,
#   'formattedAddress': '10300 Main St Suite E, Bellevue, WA 98004, USA',
#   'id': 'ChIJl0CSabBtkFQRrqopqhRluJw',
#   'latitude': 47.610329199999995,
#   'longitude': -122.20258549999998},
#  {'displayName': 'Chipotle Mexican Grill',
#   'rating': 3.8,
#   'formattedAddress': '10503 NE 4th St, Bellevue, WA 98004, USA',
#   'id': 'ChIJW4VXzodskFQRseSBkOHh9Vg',
#   'latitude': 47.6135495,
#   'longitude': -122.1997845},
#  {'displayName': 'Cinemark Reserve Lincoln Square — Dine-In 21+',
#   'rating': 4.5,
#   'formattedAddress': '500 Bellevue Way NE suit 340, Bellevue, WA 98004, USA',
#   'id': 'ChIJadMls4hskFQRqB-iUD6wmLU',
#   'latitude': 47.614579,
#   'longitude': -122.20126},
#  {'displayName': 'Desi Tadka Indian Grill',
#   'rating': 4.3,
#   'formattedAddress': '304 105th Ave NE, Bellevue, WA 98004, USA',
#   'id': 'ChIJ3y0GZ71tkFQRmK2dgqcWIOI',
#   'latitude': 47.612849399999995,
#   'longitude': -122.1997081},
#  {'displayName': 'Lao Ma Tou Hot Pot 老码头火锅',
#   'rating': 4.4,
#   'formattedAddress': '288 106th Ave NE #200, Bellevue, WA 98004, USA',
#   'id': 'ChIJLyj05b1tkFQRJOwhq9mKm4o',
#   'latitude': 47.612688399999996,
#   'longitude': -122.19840370000001},
#  {'displayName': 'La Mar Cocina Peruana Bellevue',
#   'rating': 4.6,
#   'formattedAddress': '10508 Main St, Bellevue, WA 98004, USA',
#   'id': 'ChIJQz-iSbptkFQRp4NvMytxnyI',
#   'latitude': 47.610300699999996,
#   'longitude': -122.199567},
#  {'displayName': 'Seastar Restaurant & Raw Bar',
#   'rating': 4.5,
#   'formattedAddress': '205 108th Ave NE, Bellevue, WA 98004, USA',
#   'id': 'ChIJd2uY_zUVkFQRnYtbBRLwOJg',
#   'latitude': 47.6123799,
#   'longitude': -122.1964909},
#  {'displayName': 'Monsoon Bellevue',
#   'rating': 4.3,
#   'formattedAddress': '10245 Main St Unit 103, Bellevue, WA 98004, USA',
#   'id': 'ChIJx5Zt_X1skFQRiGO0IbDii1U',
#   'latitude': 47.610059799999995,
#   'longitude': -122.2031227},
#  {'displayName': '520 Bar & Grill',
#   'rating': 4.4,
#   'formattedAddress': '10146 Main St, Bellevue, WA 98004, USA',
#   'id': 'ChIJhY1xAn5skFQR740cPn2c5Kc',
#   'latitude': 47.610300699999996,
#   'longitude': -122.20431},
#  {'displayName': "Araya's Place Vegan Thai Bellevue",
#   'rating': 4.5,
#   'formattedAddress': '10246 Main St C, Bellevue, WA 98004, USA',
#   'id': 'ChIJX1ir8n1skFQRW3dgnlJ3fp0',
#   'latitude': 47.610282399999996,
#   'longitude': -122.20304840000001},
#  {'displayName': 'Bellden Cafe',
#   'rating': 4.3,
#   'formattedAddress': '10527 Main St, Bellevue, WA 98004, USA',
#   'id': 'ChIJ56sNpH1skFQRa4jznGtK-WY',
#   'latitude': 47.610006899999995,
#   'longitude': -122.19957500000001},
#  {'displayName': 'Kura Revolving Sushi Bar',
#   'rating': 4.2,
#   'formattedAddress': '266 116th Ave NE, Bellevue, WA 98004, USA',
#   'id': 'ChIJa-kOxDltkFQRg7A5nJLZM5w',
#   'latitude': 47.612265799999996,
#   'longitude': -122.18455580000001},
#  {'displayName': "Dave & Buster's Bellevue",
#   'rating': 4,
#   'formattedAddress': '11639 NE 4th St, Bellevue, WA 98004, USA',
#   'id': 'ChIJk6fobfttkFQRIeK9XN6jkNY',
#   'latitude': 47.6127262,
#   'longitude': -122.1845741},
#  {'displayName': 'Chipotle Mexican Grill',
#   'rating': 3.4,
#   'formattedAddress': '376 116th Ave NE, Bellevue, WA 98004, USA',
#   'id': 'ChIJYz8LN41tkFQRdMadR-atjKc',
#   'latitude': 47.612679899999996,
#   'longitude': -122.1853223},
#  {'displayName': 'Solarium Kitchen & Bar',
#   'rating': 3.8,
#   'formattedAddress': '300 112th Ave SE, Bellevue, WA 98004, USA',
#   'id': 'ChIJz52GO-BtkFQR7FJgJxet_K4',
#   'latitude': 47.606913899999995,
#   'longitude': -122.1888214},
#  {'displayName': 'Amuse Bar + Restaurant',
#   'rating': 3.2,
#   'formattedAddress': '200 110th Ave NE, Bellevue, WA 98004, USA',
#   'id': 'ChIJm4PPc7xtkFQR4E9KLGaglU4',
#   'latitude': 47.6126356,
#   'longitude': -122.1928186},
#  {'displayName': 'Evergreen Point Bistro',
#   'rating': 5,
#   'formattedAddress': '71 112th Ave NE, Bellevue, WA 98004, USA',
#   'id': 'ChIJO1IAVJ9tkFQRT9O8RYD1XCQ',
#   'latitude': 47.610739699999996,
#   'longitude': -122.19122979999999},
#  {'displayName': "Poppinjay's A Cafe",
#   'rating': 4.2,
#   'formattedAddress': '150 120th Ave NE, Bellevue, WA 98005, USA',
#   'id': 'ChIJgxLWrkFtkFQRMkHthXME8wo',
#   'latitude': 47.612047,
#   'longitude': -122.17968839999999},
#  {'displayName': 'Kizuki Ramen & Izakaya',
#   'rating': 4.5,
#   'formattedAddress': '14845 Main St, Bellevue, WA 98007, USA',
#   'id': 'ChIJl4sSWkpskFQRG59oX-GVfyM',
#   'latitude': 47.609612,
#   'longitude': -122.1417149},
#  {'displayName': 'La Chingona Mexican Cuisine Bellevue',
#   'rating': 4.8,
#   'formattedAddress': '29 148th Ave SE, Bellevue, WA 98007, USA',
#   'id': 'ChIJK0J_NFFtkFQRxK1pl1y4y2w',
#   'latitude': 47.6088774,
#   'longitude': -122.14350230000001},
#  {'displayName': 'Starbucks',
#   'rating': 4.1,
#   'formattedAddress': '180 148th Ave SE, Bellevue, WA 98007, USA',
#   'id': 'ChIJ48yWhkpskFQRPDYWFGjz1fM',
#   'latitude': 47.6090903,
#   'longitude': -122.1426207},
#  {'displayName': 'Best Wok Restaurant',
#   'rating': 4.3,
#   'formattedAddress': '19 148th Ave NE, Bellevue, WA 98007, USA',
#   'id': 'ChIJDT9eTUpskFQRbGHjQb6qBvA',
#   'latitude': 47.6103307,
#   'longitude': -122.14359189999999},
#  {'displayName': '7-Eleven',
#   'rating': 2.8,
#   'formattedAddress': '15 148th Ave NE, Bellevue, WA 98007, USA',
#   'id': 'ChIJTYqOTEpskFQRjIUZ-CWfJDc',
#   'latitude': 47.6101211,
#   'longitude': -122.1435588},
#  {'displayName': 'Greek Express',
#   'rating': 4.3,
#   'formattedAddress': '14835 Main St, Bellevue, WA 98007, USA',
#   'id': 'ChIJ349-WkpskFQROukGnSeucJs',
#   'latitude': 47.609617899999996,
#   'longitude': -122.14179469999999},
#  {'displayName': 'Shell',
#   'rating': 2.6,
#   'formattedAddress': '11 148th Ave SE, Bellevue, WA 98007, USA',
#   'id': 'ChIJufz9R0pskFQRHcCWY6u0qgw',
#   'latitude': 47.609559399999995,
#   'longitude': -122.1433871},
#  {'displayName': "O'Bop",
#   'rating': 4.7,
#   'formattedAddress': '11 148th Ave SE, Bellevue, WA 98007, USA',
#   'id': 'ChIJe6ECOEpskFQRGB4VeYsyLG0',
#   'latitude': 47.6095474,
#   'longitude': -122.14330579999998},
#  {'displayName': 'Lunch on the Plate',
#   'rating': 5,
#   'formattedAddress': 'Bellevue, WA 98007, USA',
#   'id': 'ChIJiRX5BABtkFQRdqghUpCxzNg',
#   'latitude': 47.610558999999995,
#   'longitude': -122.14242579999998},
#  {'displayName': 'Wingstop',
#   'rating': 3.7,
#   'formattedAddress': '14875 Main St, Bellevue, WA 98007, USA',
#   'id': 'ChIJxXEwXkpskFQRz4KVeSenNeM',
#   'latitude': 47.6096353,
#   'longitude': -122.14142299999999},
#  {'displayName': "Menchie's Frozen Yogurt",
#   'rating': 4.3,
#   'formattedAddress': '14865 Main St, Bellevue, WA 98007, USA',
#   'id': 'ChIJccoDWUpskFQRUb5KVLAHRKw',
#   'latitude': 47.609553,
#   'longitude': -122.14151999999999},
#  {'displayName': 'STALLION',
#   'rating': 5,
#   'formattedAddress': '15053 Main St, Bellevue, WA 98007, USA',
#   'id': 'ChIJS9Jhy9NtkFQR4I_p0qD3BUo',
#   'latitude': 47.6094285,
#   'longitude': -122.13984869999997},
#  {'displayName': 'Din Tai Fung 鼎泰豐',
#   'rating': 4.5,
#   'formattedAddress': '10455 NE 8th St, Bellevue, WA 98004, USA',
#   'id': 'ChIJrcrho4dskFQROHfX02ZeENg',
#   'latitude': 47.617188299999995,
#   'longitude': -122.20077789999998},
#  {'displayName': 'Cinemark Lincoln Square Cinemas and IMAX',
#   'rating': 4.2,
#   'formattedAddress': '700 Bellevue Way NE #310, Bellevue, WA 98004, USA',
#   'id': 'ChIJJ6Ov_4VskFQRu3T8pcwahmY',
#   'latitude': 47.6168325,
#   'longitude': -122.20104289999999},
#  {'displayName': 'The Cheesecake Factory',
#   'rating': 4.1,
#   'formattedAddress': '401 Bellevue Square, Bellevue, WA 98004, USA',
#   'id': 'ChIJdSUTa4ZskFQRxsn2-IoZwto',
#   'latitude': 47.6159663,
#   'longitude': -122.20210969999998},
#  {'displayName': 'JOEY Bellevue',
#   'rating': 4.6,
#   'formattedAddress': '800 Bellevue Way NE Ste 118, Bellevue, WA 98004, USA',
#   'id': 'ChIJJ7WjO49skFQR-4IwG2Zujgg',
#   'latitude': 47.617715999999994,
#   'longitude': -122.20126299999998},
#  {'displayName': 'Earls Kitchen + Bar',
#   'rating': 4.3,
#   'formattedAddress': '700 Bellevue Way NE Unit 130, Bellevue, WA 98004, USA',
#   'id': 'ChIJkTtnrYhskFQRuAW_QTilgLQ',
#   'latitude': 47.6163485,
#   'longitude': -122.20125569999999},
#  {'displayName': 'Cactus Bellevue Square',
#   'rating': 4.4,
#   'formattedAddress': '535 Bellevue Square, Bellevue, WA 98004, USA',
#   'id': 'ChIJ8eP5VY9skFQRj_eSuT7hnhM',
#   'latitude': 47.6167922,
#   'longitude': -122.20205290000001},
#  {'displayName': "Wendy's",
#   'rating': 3.6,
#   'formattedAddress': '940 Bellevue Way NE, Bellevue, WA 98004, USA',
#   'id': 'ChIJfWGsCI9skFQRtz6-s4xwviA',
#   'latitude': 47.61904,
#   'longitude': -122.20125360000002},
#  {'displayName': "Inchin's Bamboo Garden",
#   'rating': 4.1,
#   'formattedAddress': '601 108th Ave NE Keycenter Building #120, Bellevue, WA 98004, USA',
#   'id': 'ChIJDe84_YhskFQRrY6jFMbAlrU',
#   'latitude': 47.6160572,
#   'longitude': -122.19677539999999},
#  {'displayName': 'Tavern Hall',
#   'rating': 4.3,
#   'formattedAddress': '505 Bellevue Square, Bellevue, WA 98004, USA',
#   'id': 'ChIJ3bYQeY53CEER9LMe4keT1yM',
#   'latitude': 47.616440999999995,
#   'longitude': -122.20205800000001},
#  {'displayName': 'Japonessa Sushi Cocina',
#   'rating': 4.4,
#   'formattedAddress': '500 Bellevue Way NE Suite 130, Bellevue, WA 98004, USA',
#   'id': 'ChIJN1LvMYZskFQRhDtKQaB_VWQ',
#   'latitude': 47.614850499999996,
#   'longitude': -122.200976},
#  {'displayName': 'Wild Ginger Bellevue',
#   'rating': 4.1,
#   'formattedAddress': '508 Bellevue Way NE, Bellevue, WA 98004, USA',
#   'id': 'ChIJl9MGlIlskFQRkiKWMYy2cqU',
#   'latitude': 47.6149694,
#   'longitude': -122.20127869999997},
#  {'displayName': 'Shake Shack Bellevue Square',
#   'rating': 3.6,
#   'formattedAddress': '503 Bellevue Way NE, Bellevue, WA 98004, USA',
#   'id': 'ChIJfckYPg5tkFQRJ4aBmyL5-oE',
#   'latitude': 47.6163325,
#   'longitude': -122.2019684},
#  {'displayName': 'Duke’s Seafood Bellevue',
#   'rating': 4.5,
#   'formattedAddress': '500 Bellevue Way NE Ste 212, Bellevue, WA 98004, USA',
#   'id': 'ChIJw7mdDIZskFQR9crrY1PXtpc',
#   'latitude': 47.6149075,
#   'longitude': -122.2013098},
#  {'displayName': 'Cafe Hagen (Modern Scandinavian All Day Restaurant and Cocktail Bar)',
#   'rating': 4.3,
#   'formattedAddress': '777 108th Ave NE Suite 1850, Bellevue, WA 98004, USA',
#   'id': 'ChIJPVMVVABtkFQR79rTIEQnnjI',
#   'latitude': 47.6166329,
#   'longitude': -122.1969857},
#  {'displayName': 'STK Steakhouse',
#   'rating': 4.6,
#   'formattedAddress': '610 Bellevue Way NE #110, Bellevue, WA 98004, USA',
#   'id': 'ChIJoUD1o-JtkFQRwcwHjIguOZE',
#   'latitude': 47.6159769,
#   'longitude': -122.20127719999999},
#  {'displayName': 'Boiling Point',
#   'rating': 4,
#   'formattedAddress': '1075 Bellevue Way NE, Bellevue, WA 98004, USA',
#   'id': 'ChIJcYllSY5skFQR6nwQnUGLsQA',
#   'latitude': 47.61985490000001,
#   'longitude': -122.20279520000001},
#  {'displayName': 'Cantina Monarca',
#   'rating': 4.1,
#   'formattedAddress': '504 Bellevue Way NE, Bellevue, WA 98004, USA',
#   'id': 'ChIJ-_xduBBtkFQRbiAn-xoqh9k',
#   'latitude': 47.614787799999995,
#   'longitude': -122.2012932},
#  {'displayName': 'Castilla Restaurant and Tapas Bar',
#   'rating': 4.1,
#   'formattedAddress': '504 Bellevue Square, Bellevue, WA 98004, USA',
#   'id': 'ChIJqyWGR8ttkFQRmbV4DG1N088',
#   'latitude': 47.6165048,
#   'longitude': -122.20196440000001},
#  {'displayName': 'Panera Bread',
#   'rating': 3.9,
#   'formattedAddress': '1100 Bellevue Way NE Suite 900, Bellevue, WA 98004, USA',
#   'id': 'ChIJgeoRTY5skFQRbUTOT0xjmEY',
#   'latitude': 47.6204748,
#   'longitude': -122.19956979999999},
#  {'displayName': 'Farzi Café',
#   'rating': 3.9,
#   'formattedAddress': '515 Bellevue Square, Bellevue, WA 98004, USA',
#   'id': 'ChIJfYkCkGttkFQRv4gGvJhIT7I',
#   'latitude': 47.6166203,
#   'longitude': -122.20207359999999},
#  {'displayName': 'Chick-fil-A',
#   'rating': 4.3,
#   'formattedAddress': '785 116th Ave NE, Bellevue, WA 98004, USA',
#   'id': 'ChIJic2FvopskFQRb58asxzU22E',
#   'latitude': 47.616794,
#   'longitude': -122.186212},
#  {'displayName': 'Farine Bakery & Café',
#   'rating': 4.3,
#   'formattedAddress': '11194 NE 10th St, Bellevue, WA 98004, USA',
#   'id': 'ChIJ0VK45YltkFQReLM7YdHwu2M',
#   'latitude': 47.619582799999996,
#   'longitude': -122.1913475},
#  {'displayName': 'Chutneys Bellevue',
#   'rating': 4.1,
#   'formattedAddress': 'City Square App, 938 110th Ave NE #5, Bellevue, WA 98004, USA',
#   'id': 'ChIJqaI8qextkFQRD3kVJeWS6gA',
#   'latitude': 47.618498699999996,
#   'longitude': -122.1933538},
#  {'displayName': 'Cielo Cocina Mexicana',
#   'rating': 4.4,
#   'formattedAddress': '958 111th Ave NE #101, Bellevue, WA 98004, USA',
#   'id': 'ChIJgdsj1i9tkFQROd1zHVywx3w',
#   'latitude': 47.6184044,
#   'longitude': -122.1917823},
#  {'displayName': 'The Pumphouse Bar & Grill',
#   'rating': 4.5,
#   'formattedAddress': '11802 NE 8th St, Bellevue, WA 98005, USA',
#   'id': 'ChIJM5qcUPVskFQR_1535D5ymes',
#   'latitude': 47.617782399999996,
#   'longitude': -122.1830679},
#  {'displayName': 'Woobling Korean BBQ',
#   'rating': 4.4,
#   'formattedAddress': '989 112th Ave NE #205, Bellevue, WA 98004, USA',
#   'id': 'ChIJC9jIwOBtkFQRdLhQh8gXe50',
#   'latitude': 47.619241599999995,
#   'longitude': -122.1912554},
#  {'displayName': 'Tanoor Bellevue',
#   'rating': 4.3,
#   'formattedAddress': '989 112th Ave NE #105, Bellevue, WA 98004, USA',
#   'id': 'ChIJbXvZWKdtkFQRoXDGF_-Rx3c',
#   'latitude': 47.619105999999995,
#   'longitude': -122.1913479},
#  {'displayName': 'Burger King',
#   'rating': 3.2,
#   'formattedAddress': '11723 NE 8th St, Bellevue, WA 98005, USA',
#   'id': 'ChIJy87w_19skFQRDS0TJrRvfIA',
#   'latitude': 47.616817999999995,
#   'longitude': -122.18338209999999},
#  {'displayName': 'John Howie Steak',
#   'rating': 4.5,
#   'formattedAddress': '11111 NE 8th St #125, Bellevue, WA 98004, USA',
#   'id': 'ChIJ06MLNIpskFQR9w8k4jegAIk',
#   'latitude': 47.6167847,
#   'longitude': -122.19119200000002},
#  {'displayName': 'I Love Sushi on Lake Bellevue',
#   'rating': 4.4,
#   'formattedAddress': '23 Lake Bellevue Dr, Bellevue, WA 98005, USA',
#   'id': 'ChIJ8ZMXUPVskFQRwauXeAX8OsE',
#   'latitude': 47.619049999999994,
#   'longitude': -122.18174630000001},
#  {'displayName': 'Minamoto Japanese Cuisine',
#   'rating': 4.3,
#   'formattedAddress': '11011 NE 9th St, Bellevue, WA 98004, USA',
#   'id': 'ChIJcXyzxotskFQRJStVIDo8N9k',
#   'latitude': 47.618056800000005,
#   'longitude': -122.1922324},
#  {'displayName': 'Wild Wasabi Signature',
#   'rating': 4.4,
#   'formattedAddress': '909 112th Ave NE #109, Bellevue, WA 98004, USA',
#   'id': 'ChIJpxEbFeRtkFQRlGGi7NWUrkU',
#   'latitude': 47.618223199999996,
#   'longitude': -122.19123040000001},
#  {'displayName': 'Master Bing (Bellevue) 煎饼师傅',
#   'rating': 4.9,
#   'formattedAddress': '11116 NE 10th St #201, Bellevue, WA 98004, USA',
#   'id': 'ChIJH14YNQBtkFQRgIKh2GePB6k',
#   'latitude': 47.6196622,
#   'longitude': -122.1917532},
#  {'displayName': 'The French Bakery',
#   'rating': 4,
#   'formattedAddress': '909 112th Ave NE #106, Bellevue, WA 98004, USA',
#   'id': 'ChIJCa_-oYtskFQRlSDGGMptrzc',
#   'latitude': 47.6184218,
#   'longitude': -122.19119350000001},
#  {'displayName': 'Kobe Bellevue Restaurant',
#   'rating': 4.2,
#   'formattedAddress': '850 110th Ave NE #5147, Bellevue, WA 98004, USA',
#   'id': 'ChIJ8SdzYolskFQRHPD-d1FAsmA',
#   'latitude': 47.618075999999995,
#   'longitude': -122.1933311},
#  {'displayName': 'Andiamo Italian Ristorante',
#   'rating': 4.3,
#   'formattedAddress': '938 110th Ave NE #1, Bellevue, WA 98004, USA',
#   'id': 'ChIJWcgO7otskFQRtAt-mPBzWRc',
#   'latitude': 47.6191876,
#   'longitude': -122.1934528},
#  {'displayName': 'Cafe Joy',
#   'rating': 4.2,
#   'formattedAddress': '11004 NE 11th St, Bellevue, WA 98004, USA',
#   'id': 'ChIJy7o1jjFtkFQRzh5phIdE3ig',
#   'latitude': 47.620316599999995,
#   'longitude': -122.19328549999999},
#  {'displayName': 'Starbucks',
#   'rating': 4.1,
#   'formattedAddress': '1231 116th Ave NE #25, Bellevue, WA 98004, USA',
#   'id': 'ChIJpT9jovNskFQRrE4rAq2ZW2o',
#   'latitude': 47.621118499999994,
#   'longitude': -122.18605119999998},
#  {'displayName': 'ampm',
#   'rating': 2.6,
#   'formattedAddress': '11611 NE 8th St, Bellevue, WA 98005, USA',
#   'id': 'ChIJIwSLsIpskFQRukwa7TCmJYg',
#   'latitude': 47.616935999999995,
#   'longitude': -122.184877},
#  {'displayName': 'Pasifika Grill & Bar',
#   'rating': 4.8,
#   'formattedAddress': '625 116th Ave NE, Bellevue, WA 98004, USA',
#   'id': 'ChIJ4ShA-ZRtkFQRjAO-tYV4nYU',
#   'latitude': 47.6159926,
#   'longitude': -122.18672869999997},
#  {'displayName': 'Bellevue Brewing Company - Spring District Brewpub',
#   'rating': 4.5,
#   'formattedAddress': '12190 NE District Wy, Bellevue, WA 98005, USA',
#   'id': 'ChIJIb-iht9tkFQR2WUlNBbYW9s',
#   'latitude': 47.6214656,
#   'longitude': -122.17776889999999},
#  {'displayName': 'Phở Ever',
#   'rating': 4.1,
#   'formattedAddress': '12015 NE 8th St, Bellevue, WA 98005, USA',
#   'id': 'ChIJQ90bn19skFQRWNHekYHMF0g',
#   'latitude': 47.617027799999995,
#   'longitude': -122.1793565},
#  {'displayName': 'Facing East | Taiwanese Restaurant',
#   'rating': 4.3,
#   'formattedAddress': '12736 NE Bel Red Rd, Bellevue, WA 98005, USA',
#   'id': 'ChIJ_8Dquo9skFQRx3XvidLWtAU',
#   'latitude': 47.621603799999995,
#   'longitude': -122.17027809999999},
#  {'displayName': 'The Crab Pot Bellevue',
#   'rating': 3.9,
#   'formattedAddress': '2 Lake Bellevue Dr, Bellevue, WA 98005, USA',
#   'id': 'ChIJJydJyvVskFQR-zw-Ys-EHSI',
#   'latitude': 47.6202921,
#   'longitude': -122.18053379999999},
#  {'displayName': 'The Goose Pub & Eatery',
#   'rating': 4.2,
#   'formattedAddress': '12001 NE 12th St, Bellevue, WA 98005, USA',
#   'id': 'ChIJBeN62_VskFQRolgeXT5Ho5k',
#   'latitude': 47.6197406,
#   'longitude': -122.178889},
#  {'displayName': 'GREEN APPLE DELI-(Spring Deli)',
#   'rating': 5,
#   'formattedAddress': '12288 NE District Wy #135, Bellevue, WA 98005, USA',
#   'id': 'ChIJ5RrDBfdtkFQREvVY-di169Q',
#   'latitude': 47.621639599999995,
#   'longitude': -122.17641069999999},
#  {'displayName': 'Spring Deli & Market/Greenapple Deli',
#   'rating': 4.1,
#   'formattedAddress': '12288 NE District Wy #135, Bellevue, WA 98005, USA',
#   'id': 'ChIJXzKCD1RtkFQRNdI9Qgprh-4',
#   'latitude': 47.621368,
#   'longitude': -122.17654489999998},
#  {'displayName': 'Hot Ones™ by The Goose Pub & Eatery',
#   'rating': 3,
#   'formattedAddress': '12001 NE 12th St, Bellevue, WA 98005, USA',
#   'id': 'ChIJNXrROqZtkFQRk_0Xd0XDkoo',
#   'latitude': 47.6199781,
#   'longitude': -122.17880579999999},
#  {'displayName': 'Mox Boarding House',
#   'rating': 4.7,
#   'formattedAddress': '13310 NE Bel Red Rd, Bellevue, WA 98005, USA',
#   'id': 'ChIJo8wNCFZskFQRrlQ9Fdyv2eE',
#   'latitude': 47.62273460000001,
#   'longitude': -122.1625911},
#  {'displayName': 'Tasty Szechuan',
#   'rating': 4.1,
#   'formattedAddress': '707 148th Ave NE, Bellevue, WA 98007, USA',
#   'id': 'ChIJD0hdWDVtkFQRe9_Szi0YSeA',
#   'latitude': 47.616268399999996,
#   'longitude': -122.14366700000001},
#  {'displayName': 'Los Chilangos - Bellevue',
#   'rating': 4.5,
#   'formattedAddress': '14008 NE 8th St, Bellevue, WA 98007, USA',
#   'id': 'ChIJ-aPkXRJtkFQRkQF6GuYUVKc',
#   'latitude': 47.6174415,
#   'longitude': -122.1531425},
#  {'displayName': "Dick's Drive-In",
#   'rating': 4.4,
#   'formattedAddress': '15600 NE 8th St Suite O-1, Bellevue, WA 98008, USA',
#   'id': 'ChIJk6TU-fVtkFQRHHsWN5iFekU',
#   'latitude': 47.620503299999996,
#   'longitude': -122.12976739999999},
#  {'displayName': 'Happy Lamb Hot Pot',
#   'rating': 4.4,
#   'formattedAddress': '1411 156th Ave NE STE A, Bellevue, WA 98007, USA',
#   'id': 'ChIJpc0kaKVtkFQR38bRWg4u5UU',
#   'latitude': 47.6231225,
#   'longitude': -122.13325689999999},
#  {'displayName': 'Banaras',
#   'rating': 4.4,
#   'formattedAddress': '15600 NE 8th St Suite O9, Bellevue, WA 98008, USA',
#   'id': 'ChIJJQ8XECttkFQRaKaC5o3mftY',
#   'latitude': 47.6208172,
#   'longitude': -122.1305419},
#  {'displayName': 'Ten Seconds Yunnan Rice Noodle',
#   'rating': 4,
#   'formattedAddress': '1299 156th Ave NE Ste 135, Bellevue, WA 98007, USA',
#   'id': 'ChIJURH1KkRtkFQR9SGpm7mW9PU',
#   'latitude': 47.621348499999996,
#   'longitude': -122.13323090000002},
#  {'displayName': "McDonald's",
#   'rating': 3.6,
#   'formattedAddress': '1401 156th Ave NE, Bellevue, WA 98007, USA',
#   'id': 'ChIJ2UERRaVtkFQRa1rqRwl8Juc',
#   'latitude': 47.622564499999996,
#   'longitude': -122.1329131},
#  {'displayName': 'Chipotle Mexican Grill',
#   'rating': 3.6,
#   'formattedAddress': '1328 156th Ave NE, Bellevue, WA 98007, USA',
#   'id': 'ChIJ8-2rhrptkFQRaPJt4Qp_d5I',
#   'latitude': 47.621616599999996,
#   'longitude': -122.13187889999999},
#  {'displayName': 'Nan Hot Pot',
#   'rating': 4.5,
#   'formattedAddress': '15600 NE 8th St Suite O18, Bellevue, WA 98008, USA',
#   'id': 'ChIJi_1LqIRtkFQR-2aTmtur8zw',
#   'latitude': 47.6208058,
#   'longitude': -122.1297756},
#  {'displayName': 'The French Bakery Crossroads Bellevue',
#   'rating': 4.1,
#   'formattedAddress': '15600 NE 8th St K-4, Bellevue, WA 98008, USA',
#   'id': 'ChIJz_B3r7ptkFQROmxRGhrbfbk',
#   'latitude': 47.6195375,
#   'longitude': -122.13112359999998},
#  {'displayName': 'JINYA Ramen Bar - Bellevue',
#   'rating': 4.3,
#   'formattedAddress': '15600 NE 8th St Suite 0-11, Bellevue, WA 98008, USA',
#   'id': 'ChIJN6THkLptkFQR0PMowKglf78',
#   'latitude': 47.6207918,
#   'longitude': -122.13041330000001},
#  {'displayName': 'Tutta Bella Neapolitan Pizzeria',
#   'rating': 4.2,
#   'formattedAddress': '15600 NE 8th St Suite J1, Bellevue, WA 98008, USA',
#   'id': 'ChIJ34awiLBtkFQRyOr9oKtXS58',
#   'latitude': 47.6191788,
#   'longitude': -122.13098910000001},
#  {'displayName': 'Starbucks',
#   'rating': 4.3,
#   'formattedAddress': '1350 156th Ave NE, Bellevue, WA 98007, USA',
#   'id': 'ChIJj_1WrbptkFQRLWA7-jut-cY',
#   'latitude': 47.6220661,
#   'longitude': -122.1319673},
#  {'displayName': 'Sushi Me',
#   'rating': 4.2,
#   'formattedAddress': '1299 156th Ave NE STE 145, Bellevue, WA 98007, USA',
#   'id': 'ChIJN8cpqLptkFQRF65T2iq5Qks',
#   'latitude': 47.6214016,
#   'longitude': -122.1327924},
#  {'displayName': 'Madhurai Mess',
#   'rating': 4,
#   'formattedAddress': '1424 156th Ave NE, Bellevue, WA 98007, USA',
#   'id': 'ChIJiRXr0CZtkFQRxlkUoMfgWRg',
#   'latitude': 47.6230518,
#   'longitude': -122.1320829},
#  {'displayName': 'Kwality Ice Cream Bellevue',
#   'rating': 4.2,
#   'formattedAddress': '1400 156th Ave NE, Bellevue, WA 98007, USA',
#   'id': 'ChIJYWiHGQhtkFQRhVWaSjSg71k',
#   'latitude': 47.6225696,
#   'longitude': -122.1320762},
#  {'displayName': 'Nai Brother Chinese Sauerkraut Fish',
#   'rating': 4.3,
#   'formattedAddress': '1299 156th Ave NE Ste 133, Bellevue, WA 98007, USA',
#   'id': 'ChIJ9XpRAEhtkFQRWQOhz616nWA',
#   'latitude': 47.6213282,
#   'longitude': -122.1331014},
#  {'displayName': 'Pizza Hut',
#   'rating': 3.7,
#   'formattedAddress': '15600 NE 8th St a-6, Bellevue, WA 98008, USA',
#   'id': 'ChIJF7_Ha-NtkFQRshb2JSDmsj4',
#   'latitude': 47.6173247,
#   'longitude': -122.1313113},
#  {'displayName': 'Mochinut',
#   'rating': 4.1,
#   'formattedAddress': '15600 NE 8th St, Bellevue, WA 98008, USA',
#   'id': 'ChIJId0Iyz5tkFQRNo-CTTXQBPY',
#   'latitude': 47.618893799999995,
#   'longitude': -122.13104550000001},
#  {'displayName': 'Ruchi Indian Restaurant',
#   'rating': 3.7,
#   'formattedAddress': '1360 156th Ave NE, Bellevue, WA 98007, USA',
#   'id': 'ChIJYSggTKVtkFQRMSttpBveGyI',
#   'latitude': 47.6223289,
#   'longitude': -122.13200219999999},
#  {'displayName': 'Starbucks',
#   'rating': 4,
#   'formattedAddress': '15600 NE 8th St, Bellevue, WA 98008, USA',
#   'id': 'ChIJOwOHkbBtkFQRvHXjdJeyYR4',
#   'latitude': 47.6172216,
#   'longitude': -122.1307624},
#  {'displayName': 'Bunsik',
#   'rating': 4.5,
#   'formattedAddress': '15600 NE 8th St suite o 16, Bellevue, WA 98008, USA',
#   'id': 'ChIJ-6hMFG1tkFQRRaQg-kHPP9U',
#   'latitude': 47.6208325,
#   'longitude': -122.1299319},
#  {'displayName': 'Palace Korean Bar & Grill',
#   'rating': 4,
#   'formattedAddress': 'Parking lot, 15932 NE 8th St, Bellevue, WA 98008, USA',
#   'id': 'ChIJLVdW_bltkFQRmF2obqKmMvc',
#   'latitude': 47.6173688,
#   'longitude': -122.1273197},
#  {'displayName': 'Hye Life Cafe & Bar',
#   'rating': 4.4,
#   'formattedAddress': '900 160th Ave NE Suite 1, Bellevue, WA 98008, USA',
#   'id': 'ChIJ4VMlse9tkFQR5YmWV4SOvnY',
#   'latitude': 47.61799190000001,
#   'longitude': -122.127242},
#  {'displayName': "Domino's Pizza",
#   'rating': 3.5,
#   'formattedAddress': '15920 NE 8th St Ste 5 Ste 5, Bellevue, WA 98008, USA',
#   'id': 'ChIJ5Sl-ULdtkFQR71hDYcTZcKI',
#   'latitude': 47.6174174,
#   'longitude': -122.1278639},
#  {'displayName': 'Sanyoung Surf & Turf BBQ 三羊开炭',
#   'rating': 4.6,
#   'formattedAddress': '15920 NE 8th St suite 2, Bellevue, WA 98008, USA',
#   'id': 'ChIJg3OShoRtkFQREV24bx6mp_o',
#   'latitude': 47.6175734,
#   'longitude': -122.12790869999999},
#  {'displayName': 'Joy Box Restaurant',
#   'rating': 4.1,
#   'formattedAddress': '15920 NE 8th St #1, Bellevue, WA 98008, USA',
#   'id': 'ChIJ3wyB0tptkFQRwcsSElPWzkY',
#   'latitude': 47.6176271,
#   'longitude': -122.1279096},
#  {'displayName': 'Antojitos Y Mas',
#   'rating': 4.1,
#   'formattedAddress': '16256 NE 8th St, Bellevue, WA 98008, USA',
#   'id': 'ChIJPZ3zBrltkFQRymj-Rl9B-Ts',
#   'latitude': 47.6171338,
#   'longitude': -122.1223534},
#  {'displayName': 'Churrascos La Esquina',
#   'rating': 4.1,
#   'formattedAddress': '900 160th Ave NE, Bellevue, WA 98008, USA',
#   'id': 'ChIJPyBiTt9tkFQRym3KQyZ_Wls',
#   'latitude': 47.6180686,
#   'longitude': -122.12796589999999},
#  {'displayName': 'Flavors of India',
#   'rating': -1,
#   'formattedAddress': '16000 NE 10th St, Bellevue, WA 98008, USA',
#   'id': 'ChIJAQDwarptkFQRCUTI-etb26A',
#   'latitude': 47.6193658,
#   'longitude': -122.1277828},
#  {'displayName': 'Empanadicious',
#   'rating': 5,
#   'formattedAddress': '900 160th Ave NE STE 3, Bellevue, WA 98008, USA',
#   'id': 'ChIJJwfd1AltkFQRTztW41_3nII',
#   'latitude': 47.61799190000001,
#   'longitude': -122.127242},
#  {'displayName': 'Looking for Chai Taiwanese Kitchen',
#   'rating': 4.4,
#   'formattedAddress': '12121 Northup Way #205, Bellevue, WA 98005, USA',
#   'id': 'ChIJq8KMPuVskFQRHt2uy0YCBQA',
#   'latitude': 47.6305932,
#   'longitude': -122.17905630000001},
#  {'displayName': 'Subway',
#   'rating': 3.9,
#   'formattedAddress': '12121 Northup Way #215, Bellevue, WA 98005, USA',
#   'id': 'ChIJTVulF-VskFQR6JN5QdVlo4c',
#   'latitude': 47.6300394,
#   'longitude': -122.17837069999999},
#  {'displayName': 'Mercurys Coffee Co.',
#   'rating': 4.4,
#   'formattedAddress': '13102 NE 20th St, Bellevue, WA 98005, USA',
#   'id': 'ChIJwXyjgP5skFQRbKQjyqmj2qs',
#   'latitude': 47.628321,
#   'longitude': -122.16556600000001},
#  {'displayName': 'Cascadia Pizza Restaurant and Brewery',
#   'rating': 4.8,
#   'formattedAddress': '1820 130th Ave NE Suite 2, Bellevue, WA 98005, USA',
#   'id': 'ChIJL3LXNa5tkFQRBDUFokv1kC0',
#   'latitude': 47.6266022,
#   'longitude': -122.16617579999998},
#  {'displayName': 'Dan Gui Sichuan Cuisine',
#   'rating': 4.2,
#   'formattedAddress': '13112 NE 20th St, Bellevue, WA 98005, USA',
#   'id': 'ChIJN5sDHzZtkFQRKM7mhv3SE-s',
#   'latitude': 47.628839199999994,
#   'longitude': -122.16567339999999},
#  {'displayName': 'Royal Kitchen',
#   'rating': 3.8,
#   'formattedAddress': '13200 NE 20th St Ste 400, Bellevue, WA 98005, USA',
#   'id': 'ChIJcf9Cfv5skFQRzaQYxfRR280',
#   'latitude': 47.6284831,
#   'longitude': -122.16427440000001},
#  {'displayName': "Angelo's of Bellevue",
#   'rating': 4.4,
#   'formattedAddress': '1830 130th Ave NE, Bellevue, WA 98005, USA',
#   'id': 'ChIJuxQ7sv5skFQRaocSrE5W6GM',
#   'latitude': 47.6269302,
#   'longitude': -122.1665802},
#  {'displayName': 'Shahana Steakhouse (Burger n Gyros)',
#   'rating': 4.5,
#   'formattedAddress': '2285 140th Ave NE, Bellevue, WA 98005, USA',
#   'id': 'ChIJBX3qd7JykFQRC7Wd_Ob5yJU',
#   'latitude': 47.630133099999995,
#   'longitude': -122.15596860000001},
#  {'displayName': 'Papa Johns Pizza',
#   'rating': 3.8,
#   'formattedAddress': '13600 NE 20th St, Bellevue, WA 98005, USA',
#   'id': 'ChIJ1xgOmY9skFQRsB3MNyS4K9s',
#   'latitude': 47.6282211,
#   'longitude': -122.15890379999998},
#  {'displayName': 'Ramen Nori',
#   'rating': 4.7,
#   'formattedAddress': '13112 NE 20th St #200, Bellevue, WA 98005, USA',
#   'id': 'ChIJuUA3NI5tkFQRTx_4QUqxey4',
#   'latitude': 47.628839199999994,
#   'longitude': -122.16567339999999},
#  {'displayName': 'Caspian Bellevue',
#   'rating': 4,
#   'formattedAddress': '1806 136th Pl NE, Bellevue, WA 98005, USA',
#   'id': 'ChIJJ0ipIABtkFQR393hjooyMxw',
#   'latitude': 47.6263037,
#   'longitude': -122.1569432},
#  {'displayName': 'Chili Master 湘巴佬',
#   'rating': 4.9,
#   'formattedAddress': '13433 NE 20th St Suite A, Bellevue, WA 98005, USA',
#   'id': 'ChIJ4ReKuGFtkFQRhDi-TB_QkE8',
#   'latitude': 47.627702899999996,
#   'longitude': -122.15987580000001},
#  {'displayName': "Sugee's Box Lunch Company",
#   'rating': 4.7,
#   'formattedAddress': '13225 NE 20th St, Bellevue, WA 98005, USA',
#   'id': 'ChIJM4HxbP5skFQRs_moazE50ZE',
#   'latitude': 47.6270622,
#   'longitude': -122.1626337},
#  {'displayName': 'ampm',
#   'rating': 2,
#   'formattedAddress': '12903 NE 20th St, Bellevue, WA 98005, USA',
#   'id': 'ChIJUxhTEPxskFQR9VCHYyIBs-8',
#   'latitude': 47.6276757,
#   'longitude': -122.16788509999999},
#  {'displayName': 'DongBei Harvest 东北人家',
#   'rating': 4,
#   'formattedAddress': '13433 NE 20th St G, Bellevue, WA 98005, USA',
#   'id': 'ChIJMdMJg1xtkFQRL1Yya5o0rNE',
#   'latitude': 47.627721199999996,
#   'longitude': -122.1601626},
#  {'displayName': 'Kin Dee Bellevue',
#   'rating': 4.9,
#   'formattedAddress': '13238 NE 20th St Suite 100, Bellevue, WA 98005, USA',
#   'id': 'ChIJizpdHRptkFQREzbGlJ7pvic',
#   'latitude': 47.628524399999996,
#   'longitude': -122.16394950000002},
#  {'displayName': 'Market Seoul',
#   'rating': -1,
#   'formattedAddress': '13622 NE 20th St Suite D, Bellevue, WA 98005, USA',
#   'id': 'ChIJRemB2kJtkFQRMDLps8NIzes',
#   'latitude': 47.6283482,
#   'longitude': -122.1579075},
#  {'displayName': 'Honest Restaurant',
#   'rating': 3.8,
#   'formattedAddress': '2241 148th Ave NE, Bellevue, WA 98007, USA',
#   'id': 'ChIJQQOEpfptkFQR88IiUF_6EnI',
#   'latitude': 47.6306838,
#   'longitude': -122.1451578},
#  {'displayName': 'MTR - Mavalli Tiffin Rooms',
#   'rating': 3.5,
#   'formattedAddress': '14625 NE 24th St Suite 3, Bellevue, WA 98007, USA',
#   'id': 'ChIJKdbZe1NtkFQRriv_LggP-Io',
#   'latitude': 47.6310207,
#   'longitude': -122.14488300000001},
#  {'displayName': "McDonald's",
#   'rating': 3.7,
#   'formattedAddress': '13841 NE 20th St, Bellevue, WA 98005, USA',
#   'id': 'ChIJPfieWABtkFQRmHQ_Cg8SOdQ',
#   'latitude': 47.6275603,
#   'longitude': -122.15459860000001},
#  {'displayName': '85°C Bakery Cafe - Bellevue',
#   'rating': 4,
#   'formattedAddress': '14701 NE 20th St, Bellevue, WA 98007, USA',
#   'id': 'ChIJVRQbBtBtkFQRR8rlQ6SWfBY',
#   'latitude': 47.627645699999995,
#   'longitude': -122.14443969999999},
#  {'displayName': 'Supreme Dumplings',
#   'rating': 4.6,
#   'formattedAddress': '14603 NE 20th St #4B, Bellevue, WA 98007, USA',
#   'id': 'ChIJ_fbAUWVtkFQRqLBlBvTTYVA',
#   'latitude': 47.6267547,
#   'longitude': -122.1450034},
#  {'displayName': 'Shaoshan Impression',
#   'rating': 4.2,
#   'formattedAddress': '14150 NE 20th St Ste C, Bellevue, WA 98007, USA',
#   'id': 'ChIJyzE8HEFtkFQRqlFSu2PzSns',
#   'latitude': 47.628349299999996,
#   'longitude': -122.15152499999998},
#  {'displayName': 'Chaat House',
#   'rating': 4,
#   'formattedAddress': '14725 NE 20th St, Bellevue, WA 98007, USA',
#   'id': 'ChIJw1PmRahtkFQRf1A2-8KFbAY',
#   'latitude': 47.6275173,
#   'longitude': -122.14375309999998},
#  {'displayName': 'Taco Bell',
#   'rating': 3.8,
#   'formattedAddress': '1960 148th Ave NE, Redmond, WA 98052, USA',
#   'id': 'ChIJUTI-XahtkFQRinovfbInDV4',
#   'latitude': 47.6274581,
#   'longitude': -122.1427305},
#  {'displayName': 'Sun Sui Wah Seafood Restaurant',
#   'rating': 3.4,
#   'formattedAddress': '14505 NE 20th St Suite R, Bellevue, WA 98007, USA',
#   'id': 'ChIJrRoYbABtkFQRuO9YVfx_DDc',
#   'latitude': 47.627480500000004,
#   'longitude': -122.1465107},
#  {'displayName': 'IHOP',
#   'rating': 4.1,
#   'formattedAddress': '14747 NE 20th St, Bellevue, WA 98007, USA',
#   'id': 'ChIJ1bG5UahtkFQRlt8q4CaRUwU',
#   'latitude': 47.627114899999995,
#   'longitude': -122.143647},
#  {'displayName': 'Núodle',
#   'rating': 3.9,
#   'formattedAddress': '14603 NE 20th St #6, Bellevue, WA 98007, USA',
#   'id': 'ChIJsUFKrKltkFQRIknWBbPUeio',
#   'latitude': 47.626832199999996,
#   'longitude': -122.1445249},
#  {'displayName': 'Gyu-Kaku Japanese BBQ',
#   'rating': 4.2,
#   'formattedAddress': '14506 NE 20th St #2, Bellevue, WA 98007, USA',
#   'id': 'ChIJEXqrKqhtkFQRe2Xie0--puE',
#   'latitude': 47.628195299999994,
#   'longitude': -122.14614630000001},
#  {'displayName': 'Rasoi Indian Restaurant and Bakery',
#   'rating': 4.4,
#   'formattedAddress': '14339 NE 20th St Ste I, Bellevue, WA 98007, USA',
#   'id': 'ChIJJ6v8Vm5tkFQRqZLWQZLFw38',
#   'latitude': 47.6271363,
#   'longitude': -122.1489197},
#  {'displayName': 'Anjappar Seattle Indian Restaurant',
#   'rating': 3.7,
#   'formattedAddress': '14625 NE 24th St, Bellevue, WA 98007, USA',
#   'id': 'ChIJiy0l1wdtkFQR59HQyOyqv4A',
#   'latitude': 47.6311586,
#   'longitude': -122.14517609999999},
#  {'displayName': 'Frying Fish',
#   'rating': 4.4,
#   'formattedAddress': '1915 140th Ave NE #2347, Bellevue, WA 98005, USA',
#   'id': 'ChIJHRQNBxhskFQRbIgH4Gh28ic',
#   'latitude': 47.627047700000006,
#   'longitude': -122.1543171},
#  {'displayName': 'Liuyishou Hotpot',
#   'rating': 4.4,
#   'formattedAddress': '1644 140th Ave NE, Bellevue, WA 98005, USA',
#   'id': 'ChIJF6Q8F_FtkFQRVSNnJdLAsyQ',
#   'latitude': 47.625420399999996,
#   'longitude': -122.15314140000001},
#  {'displayName': 'Dough Zone Dumpling House Overlake',
#   'rating': 4.4,
#   'formattedAddress': '14625 NE 24th St #4b, Bellevue, WA 98007, USA',
#   'id': 'ChIJh0ZU1gdtkFQRhRYYEFQaNb0',
#   'latitude': 47.6311077,
#   'longitude': -122.1449732},
#  {'displayName': 'MonGa Café',
#   'rating': 4.2,
#   'formattedAddress': '14603 NE 20th St, Bellevue, WA 98007, USA',
#   'id': 'ChIJ84WEpaltkFQRh3HXheNKzns',
#   'latitude': 47.626871099999995,
#   'longitude': -122.1452053},
#  {'displayName': 'Timeless Tea (Bellevue)',
#   'rating': 4.2,
#   'formattedAddress': '14320 NE 20th St ste d, Bellevue, WA 98007, USA',
#   'id': 'ChIJl3AxSdhtkFQRflGKXUZHNNA',
#   'latitude': 47.6282278,
#   'longitude': -122.1493253},
#  {'displayName': 'Donburi Station Bellevue',
#   'rating': 4.4,
#   'formattedAddress': '14339 NE 20th St Ste E, Bellevue, WA 98007, USA',
#   'id': 'ChIJLdjYX59tkFQRud31PPNm9S4',
#   'latitude': 47.627410999999995,
#   'longitude': -122.149031},
#  {'displayName': 'Dosa House',
#   'rating': 4,
#   'formattedAddress': '15259 NE Bel Red Rd, Bellevue, WA 98007, USA',
#   'id': 'ChIJse098aZtkFQRjiy3Fe1l8Zw',
#   'latitude': 47.6281877,
#   'longitude': -122.1355835},
#  {'displayName': 'Can Am Pizza',
#   'rating': 4.2,
#   'formattedAddress': '2125 NE Bel Red Rd, Redmond, WA 98052, USA',
#   'id': 'ChIJ88D0631skFQR15tP90fZ2no',
#   'latitude': 47.6295645,
#   'longitude': -122.13527230000001},
#  {'displayName': "Jack's BBQ & Steakhouse Bellevue | Redmond",
#   'rating': 4.3,
#   'formattedAddress': '2115 NE Bel Red Rd, Redmond, WA 98052, USA',
#   'id': 'ChIJKRdqeABtkFQRtkeBB7rhLFY',
#   'latitude': 47.6292817,
#   'longitude': -122.13561919999998},
#  {'displayName': 'Shinya Shokudō',
#   'rating': 4.4,
#   'formattedAddress': '2020 148th Ave NE, Redmond, WA 98052, USA',
#   'id': 'ChIJE6GJWNhtkFQRBsJJei6xsig',
#   'latitude': 47.6281915,
#   'longitude': -122.1411625},
#  {'displayName': 'Mediterranean Grill',
#   'rating': 4.3,
#   'formattedAddress': '15253 NE Bel Red Rd, Bellevue, WA 98007, USA',
#   'id': 'ChIJr6ZQ5qZtkFQRSkspoPABooE',
#   'latitude': 47.628699999999995,
#   'longitude': -122.135027},
#  {'displayName': 'Tapioca Express',
#   'rating': 3.9,
#   'formattedAddress': '15230 NE 24th St, Redmond, WA 98052, USA',
#   'id': 'ChIJE4jaAAptkFQRSWhnmn8JNb8',
#   'latitude': 47.631983700000006,
#   'longitude': -122.13586509999999},
#  {'displayName': "Arby's",
#   'rating': 4,
#   'formattedAddress': '15115 NE 24th St, Redmond, WA 98052, USA',
#   'id': 'ChIJmRG62gltkFQRM6oEgTXaX1k',
#   'latitude': 47.6313223,
#   'longitude': -122.1390156},
#  {'displayName': 'Crimson Coward',
#   'rating': 4,
#   'formattedAddress': '2028 148th Ave NE, Redmond, WA 98052, USA',
#   'id': 'ChIJ0xbF0h9tkFQRKa1fET3rg_c',
#   'latitude': 47.6282066,
#   'longitude': -122.14142179999999},
#  {'displayName': 'Foody moody halal Indian Pakistani cuisine',
#   'rating': 4.8,
#   'formattedAddress': '2444 NE Bel Red Rd, Bellevue, WA 98007, USA',
#   'id': 'ChIJE0w6f3lDkFQRIkEnaMQLg4c',
#   'latitude': 47.6319169,
#   'longitude': -122.13294359999998},
#  {'displayName': 'Pagliacci Pizza',
#   'rating': 4.5,
#   'formattedAddress': '15238 NE Bel Red Rd, Bellevue, WA 98007, USA',
#   'id': 'ChIJRZe_V6ZtkFQRpe6nTXrxOUo',
#   'latitude': 47.628109,
#   'longitude': -122.135945},
#  {'displayName': 'Tian Tian Noodles',
#   'rating': 4,
#   'formattedAddress': '15230 NE 24th St, Redmond, WA 98052, USA',
#   'id': 'ChIJTwRoAgptkFQRFFQni1gG8qs',
#   'latitude': 47.631916399999994,
#   'longitude': -122.1359298},
#  {'displayName': 'El Maestro del Taco',
#   'rating': 4.7,
#   'formattedAddress': '1836 156th Ave NE, Bellevue, WA 98007, USA',
#   'id': 'ChIJcw9b0rZtkFQREINY01y7mME',
#   'latitude': 47.626999399999995,
#   'longitude': -122.1306505},
#  {'displayName': 'Sukhothai Restaurant',
#   'rating': 4.3,
#   'formattedAddress': '15045 NE Bel Red Rd, Bellevue, WA 98007, USA',
#   'id': 'ChIJHYF1PKZtkFQRIewG3ZWWSzM',
#   'latitude': 47.6272927,
#   'longitude': -122.13832470000001},
#  {'displayName': '7-Eleven',
#   'rating': 2.2,
#   'formattedAddress': '15521 NE Bel Red Rd, Bellevue, WA 98007, USA',
#   'id': 'ChIJkzR1maBtkFQRS_b_zXMpay0',
#   'latitude': 47.631827699999995,
#   'longitude': -122.13329729999998},
#  {'displayName': 'Potbelly Sandwich Shop',
#   'rating': 4,
#   'formattedAddress': '15425 NE 24th St, Bellevue, WA 98007, USA',
#   'id': 'ChIJZXfheSdskFQRicl8XRZe_d0',
#   'latitude': 47.630731399999995,
#   'longitude': -122.13403129999999},
#  {'displayName': 'Teapot Vegetarian House',
#   'rating': 4.2,
#   'formattedAddress': '15230 NE 24th St Ste H, Redmond, WA 98052, USA',
#   'id': 'ChIJE4jaAAptkFQRCeka4cpRkOI',
#   'latitude': 47.631927399999995,
#   'longitude': -122.13665999999998},
#  {'displayName': "Miah's Kitchen",
#   'rating': 4,
#   'formattedAddress': '2022 148th Ave NE #13b, Redmond, WA 98052, USA',
#   'id': 'ChIJZ_AWgX93CEERlF5MCNVchOY',
#   'latitude': 47.6282,
#   'longitude': -122.14127780000001},
#  {'displayName': "Jimmy John's",
#   'rating': 3.5,
#   'formattedAddress': '15253 NE Bel Red Rd, Bellevue, WA 98007, USA',
#   'id': 'ChIJDz_l5aZtkFQR0JxWrMJJlF8',
#   'latitude': 47.6286077,
#   'longitude': -122.13509940000002},
#  {'displayName': 'La Tía Angelina',
#   'rating': 4.5,
#   'formattedAddress': '2444 NE Bel Red Rd, Redmond, WA 98052, USA',
#   'id': 'ChIJR4_zXR9tkFQRR7gn-iENrC8',
#   'latitude': 47.6319169,
#   'longitude': -122.13294359999998},
#  {'displayName': 'Depot Point',
#   'rating': -1,
#   'formattedAddress': '2018 156th Ave NE, Bellevue, WA 98007, USA',
#   'id': 'ChIJ5cWDaKFtkFQRgqjPMA-3sI0',
#   'latitude': 47.629002199999995,
#   'longitude': -122.1299993}]

# %% [markdown]
# Now that we have all the place information we need, we'll write this data to a spreadsheet for future use. We'll do that using pandas.

# %%
import pandas as pd

df = pd.DataFrame(all_places)
df.to_csv("places.csv", index=False)

# %% [markdown]
# So with this list of places and their IDs, we can run each ID through the Places API to each place's reviews. We'll do so using the Place Details (New) endpoint. We can only make 1,000 requests per month to keep the project free.

# %%
import pandas as pd

df = pd.read_csv("places.csv")

ids = df["id"].tolist()

# %%
import requests
reviews_df = pd.DataFrame(columns=["name",
                                   "relativePublishTimeDescription",
                                   "rating",
                                   "text", "originalText",
                                   "authorAttribution",
                                   "publishTime",
                                   "flagContentUri", "googleMapsUri"])

headers = {
    "Content-Type": "application/json",
    "X-Goog-Api-Key": API_KEY,
    "X-Goog-FieldMask": "id,displayName,reviews"
}

rows = []
num_requests = 0
for curr_id in ids:
    url = "https://places.googleapis.com/v1/places/" + curr_id
    response = requests.get(url, headers=headers)
    num_requests += 1
    if response.status_code == 200:
        data = response.json()
        reviews = data.get("reviews", [])
        
        for r in reviews:
            rows.append({
                "name": r.get('name', 'Unknown'),
                "relativePublishTimeDescription": r.get('relativePublishTimeDescription', 'Unknown'),
                "rating": r.get('rating', 'Unknown'),
                "text": r.get("text", "No review found"),
                "originalText": r.get("originalText", "No review found"),
                "authorAttribution": r.get("authorAttribution", "No author found"),
                "publishTime": r.get("publishTime", "N/A"),
                "flagContentUri": r.get("flagContentUri", "N/A"),
                "googleMapsUri": r.get("googleMapsUri", "N/A")
            })
print(f"Made {num_requests} requests.")
# Out:
# Made 192 requests.

# %%
reviews_df = pd.DataFrame(rows)

# %%
reviews_df
# Out:
#                                                   name  \
# 0    places/ChIJUaS2CnRskFQRgkVy8FFKcKE/reviews/Chd...
# 1    places/ChIJUaS2CnRskFQRgkVy8FFKcKE/reviews/Chd...
# 2    places/ChIJUaS2CnRskFQRgkVy8FFKcKE/reviews/ChZ...
# 3    places/ChIJUaS2CnRskFQRgkVy8FFKcKE/reviews/Chd...
# 4    places/ChIJUaS2CnRskFQRgkVy8FFKcKE/reviews/ChZ...
# ..                                                 ...
# 931  places/ChIJR4_zXR9tkFQRR7gn-iENrC8/reviews/Chd...
# 932  places/ChIJR4_zXR9tkFQRR7gn-iENrC8/reviews/Chd...
# 933  places/ChIJR4_zXR9tkFQRR7gn-iENrC8/reviews/ChZ...
# 934  places/ChIJR4_zXR9tkFQRR7gn-iENrC8/reviews/Chd...
# 935  places/ChIJR4_zXR9tkFQRR7gn-iENrC8/reviews/Chd...
#
#     relativePublishTimeDescription  rating  \
# 0                      a month ago       4
# 1                      3 weeks ago       2
# 2                    10 months ago       5
# 3                      a month ago       3
# 4                     2 months ago       5
# ..                             ...     ...
# 931                  10 months ago       4
# 932                   7 months ago       5
# 933                     a year ago       2
# 934                   6 months ago       3
# 935                   4 months ago       5
#
#                                                   text  \
# 0    {'text': 'They have very nice grab n go option...
# 1    {'text': 'I had seen plenty of bad reviews abo...
# 2    {'text': 'Large space, tasty menu options, and...
# 3    {'text': 'Ok, so I've been here a few times an...
# 4    {'text': 'uh oh found another favorite that's ...
# ..                                                 ...
# 931  {'text': 'Shocked and pleasantly surprised tha...
# 932  {'text': 'This is definitely the BEST Mexican ...
# 933  {'text': 'I ordered the birria torta and two a...
# 934  {'text': 'food here is 3/5, quesadilla is fine...
# 935  {'text': 'As someone from SoCal, I've been loo...
#
#                                           originalText  \
# 0    {'text': 'They have very nice grab n go option...
# 1    {'text': 'I had seen plenty of bad reviews abo...
# 2    {'text': 'Large space, tasty menu options, and...
# 3    {'text': 'Ok, so I've been here a few times an...
# 4    {'text': 'uh oh found another favorite that's ...
# ..                                                 ...
# 931  {'text': 'Shocked and pleasantly surprised tha...
# 932  {'text': 'This is definitely the BEST Mexican ...
# 933  {'text': 'I ordered the birria torta and two a...
# 934  {'text': 'food here is 3/5, quesadilla is fine...
# 935  {'text': 'As someone from SoCal, I've been loo...
#
#                                      authorAttribution  \
# 0    {'displayName': 'Shana Bobbitt', 'uri': 'https...
# 1    {'displayName': 'Kelly Lee', 'uri': 'https://w...
# 2    {'displayName': 'Ksusha Malysheva', 'uri': 'ht...
# 3    {'displayName': 'Mick Thornton', 'uri': 'https...
# 4    {'displayName': 'Jisoo Jeong', 'uri': 'https:/...
# ..                                                 ...
# 931  {'displayName': 'S S', 'uri': 'https://www.goo...
# 932  {'displayName': 'Jeffrey Chappon', 'uri': 'htt...
# 933  {'displayName': 'Tricia Ward', 'uri': 'https:/...
# 934  {'displayName': 'eve', 'uri': 'https://www.goo...
# 935  {'displayName': 'Casidar Alex', 'uri': 'https:...
#
#                      publishTime  \
# 0    2025-05-08T21:42:41.981034Z
# 1    2025-06-10T23:12:31.737849Z
# 2    2024-08-23T22:37:49.628667Z
# 3    2025-06-02T18:41:12.863221Z
# 4    2025-04-16T23:23:13.411396Z
# ..                           ...
# 931  2024-08-12T00:46:35.369292Z
# 932  2024-11-12T22:07:36.423790Z
# 933  2023-12-30T01:52:03.339267Z
# 934  2024-12-26T17:38:11.917088Z
# 935  2025-02-11T20:56:49.384578Z
#
#                                         flagContentUri  \
# 0    https://www.google.com/local/review/rap/report...
# 1    https://www.google.com/local/review/rap/report...
# 2    https://www.google.com/local/review/rap/report...
# 3    https://www.google.com/local/review/rap/report...
# 4    https://www.google.com/local/review/rap/report...
# ..                                                 ...
# 931  https://www.google.com/local/review/rap/report...
# 932  https://www.google.com/local/review/rap/report...
# 933  https://www.google.com/local/review/rap/report...
# 934  https://www.google.com/local/review/rap/report...
# 935  https://www.google.com/local/review/rap/report...
#
#                                          googleMapsUri
# 0    https://www.google.com/maps/reviews/data=!4m6!...
# 1    https://www.google.com/maps/reviews/data=!4m6!...
# 2    https://www.google.com/maps/reviews/data=!4m6!...
# 3    https://www.google.com/maps/reviews/data=!4m6!...
# 4    https://www.google.com/maps/reviews/data=!4m6!...
# ..                                                 ...
# 931  https://www.google.com/maps/reviews/data=!4m6!...
# 932  https://www.google.com/maps/reviews/data=!4m6!...
# 933  https://www.google.com/maps/reviews/data=!4m6!...
# 934  https://www.google.com/maps/reviews/data=!4m6!...
# 935  https://www.google.com/maps/reviews/data=!4m6!...
#
# [936 rows x 9 columns]

# %%
# Cleaning up the name column to display a human-readable ID and raw strings for review text
reviews_df["name"] = reviews_df["name"].str.split("/").str[1]
reviews_df["text"] = reviews_df["text"].apply(lambda x: x.get("text") if isinstance(x, dict) else x)
reviews_df
# Out:
#                             name relativePublishTimeDescription  rating  \
# 0    ChIJUaS2CnRskFQRgkVy8FFKcKE                    a month ago       4
# 1    ChIJUaS2CnRskFQRgkVy8FFKcKE                    3 weeks ago       2
# 2    ChIJUaS2CnRskFQRgkVy8FFKcKE                  10 months ago       5
# 3    ChIJUaS2CnRskFQRgkVy8FFKcKE                    a month ago       3
# 4    ChIJUaS2CnRskFQRgkVy8FFKcKE                   2 months ago       5
# ..                           ...                            ...     ...
# 931  ChIJR4_zXR9tkFQRR7gn-iENrC8                  10 months ago       4
# 932  ChIJR4_zXR9tkFQRR7gn-iENrC8                   7 months ago       5
# 933  ChIJR4_zXR9tkFQRR7gn-iENrC8                     a year ago       2
# 934  ChIJR4_zXR9tkFQRR7gn-iENrC8                   6 months ago       3
# 935  ChIJR4_zXR9tkFQRR7gn-iENrC8                   4 months ago       5
#
#                                                   text  \
# 0    They have very nice grab n go options but are ...
# 1    I had seen plenty of bad reviews about the cus...
# 2    Large space, tasty menu options, and stylish d...
# 3    Ok, so I've been here a few times and it's a n...
# 4    uh oh found another favorite that's far far fr...
# ..                                                 ...
# 931  Shocked and pleasantly surprised that a food t...
# 932  This is definitely the BEST Mexican food I’ve ...
# 933  I ordered the birria torta and two al pastor t...
# 934  food here is 3/5, quesadilla is fine, but burr...
# 935  As someone from SoCal, I've been looking for a...
#
#                                           originalText  \
# 0    {'text': 'They have very nice grab n go option...
# 1    {'text': 'I had seen plenty of bad reviews abo...
# 2    {'text': 'Large space, tasty menu options, and...
# 3    {'text': 'Ok, so I've been here a few times an...
# 4    {'text': 'uh oh found another favorite that's ...
# ..                                                 ...
# 931  {'text': 'Shocked and pleasantly surprised tha...
# 932  {'text': 'This is definitely the BEST Mexican ...
# 933  {'text': 'I ordered the birria torta and two a...
# 934  {'text': 'food here is 3/5, quesadilla is fine...
# 935  {'text': 'As someone from SoCal, I've been loo...
#
#                                      authorAttribution  \
# 0    {'displayName': 'Shana Bobbitt', 'uri': 'https...
# 1    {'displayName': 'Kelly Lee', 'uri': 'https://w...
# 2    {'displayName': 'Ksusha Malysheva', 'uri': 'ht...
# 3    {'displayName': 'Mick Thornton', 'uri': 'https...
# 4    {'displayName': 'Jisoo Jeong', 'uri': 'https:/...
# ..                                                 ...
# 931  {'displayName': 'S S', 'uri': 'https://www.goo...
# 932  {'displayName': 'Jeffrey Chappon', 'uri': 'htt...
# 933  {'displayName': 'Tricia Ward', 'uri': 'https:/...
# 934  {'displayName': 'eve', 'uri': 'https://www.goo...
# 935  {'displayName': 'Casidar Alex', 'uri': 'https:...
#
#                      publishTime  \
# 0    2025-05-08T21:42:41.981034Z
# 1    2025-06-10T23:12:31.737849Z
# 2    2024-08-23T22:37:49.628667Z
# 3    2025-06-02T18:41:12.863221Z
# 4    2025-04-16T23:23:13.411396Z
# ..                           ...
# 931  2024-08-12T00:46:35.369292Z
# 932  2024-11-12T22:07:36.423790Z
# 933  2023-12-30T01:52:03.339267Z
# 934  2024-12-26T17:38:11.917088Z
# 935  2025-02-11T20:56:49.384578Z
#
#                                         flagContentUri  \
# 0    https://www.google.com/local/review/rap/report...
# 1    https://www.google.com/local/review/rap/report...
# 2    https://www.google.com/local/review/rap/report...
# 3    https://www.google.com/local/review/rap/report...
# 4    https://www.google.com/local/review/rap/report...
# ..                                                 ...
# 931  https://www.google.com/local/review/rap/report...
# 932  https://www.google.com/local/review/rap/report...
# 933  https://www.google.com/local/review/rap/report...
# 934  https://www.google.com/local/review/rap/report...
# 935  https://www.google.com/local/review/rap/report...
#
#                                          googleMapsUri
# 0    https://www.google.com/maps/reviews/data=!4m6!...
# 1    https://www.google.com/maps/reviews/data=!4m6!...
# 2    https://www.google.com/maps/reviews/data=!4m6!...
# 3    https://www.google.com/maps/reviews/data=!4m6!...
# 4    https://www.google.com/maps/reviews/data=!4m6!...
# ..                                                 ...
# 931  https://www.google.com/maps/reviews/data=!4m6!...
# 932  https://www.google.com/maps/reviews/data=!4m6!...
# 933  https://www.google.com/maps/reviews/data=!4m6!...
# 934  https://www.google.com/maps/reviews/data=!4m6!...
# 935  https://www.google.com/maps/reviews/data=!4m6!...
#
# [936 rows x 9 columns]

# %%
reviews_df.to_csv("reviews.csv")
